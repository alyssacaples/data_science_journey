# %%
import requests
from bs4 import BeautifulSoup as bs
import re

# %%
#get info from webpage
r = requests.get("https://everydaypower.com/jaden-smith-quotes/")

#convert to a beautiful soup object
soup = bs(r.content)

#prints out elements in a pretty way
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#  <head>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MLQRSLV');
#   </script>
#  </head>
#  <meta content="IxGWcPZDVdM6Zno8XpzVn8Xjh7kqlvfHPTi_NcHsojY" name="google-site-verification"/>
#  <link href="https://cdn.everydaypower.com/manifest.json" rel="manifest"/>
#  <meta content="4b38f6f0cac237132f2ca4752b63077a" name="p:domain_verify"/>
#  <meta content="PcgideDB1QAVkIJ63HOlXBh-EW1gatClL1RNYEMZcVU" name="google-site-verification"/>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" id="viewport" name="viewport"/>
#  <link href="https://cdn.everydaypower.com/wp-content/uploads/2018/04/everydaypowerblog-favicon.png" rel="shortcut icon"/>
#  <meta content="article" property="og:type"/>
#  <meta content="https://cdn.everydaypower.com/wp-content/uploads/2018/11/50-Jaden-Smith-Quotes-That-Expand-Your-Mindset-1000x600.jpg" property="og:image"/>
#  <meta content="https://cdn.everydaypower.com/wp-content/uploads/2018/11/50-Jaden-Smith-Quotes-That-Expand-Your-Mindset-1000x600.jpg" name="twitter:image"/>
#  <meta content="https://everydaypower.com/jaden-smith-quotes/" property="og:url"/>
#  <meta content="50 Jaden Smith Quotes That Expand Your Mindset" property="og:title"/>
#  <meta content="Never let anyone else's light overshadow you. Read these Jaden Smith quotes to find out how." property="og:description"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="https://everydaypower.com/jaden-smith-quotes/" name="twitter:url"/>
#  <meta content="50 Jaden Smith Quotes That Expand Your Mindset" name="twitter:title"/>
#  <meta content="Never let anyone else's light overshadow you. Read these Jaden Smith quotes to find out how." name="twitter:description"/>
#  <meta content="article" property="og:type"/>
#  <meta content="%%title%% (2019)" property="og:title"/>
#  <meta content="Looking for the best Jaden Smith quotes? Check out our collection of quotes from the young rapper and actor that'll expand your mindset." property="og:description"/>
#  <meta content="https://everydaypower.com/jaden-smith-quotes/" property="og:url"/>
#  <meta content="Everyday Power" property="og:site_name"/>
#  <meta content="2020-06-30T14:29:12-04:00" property="og:updated_time"/>
#  <meta content="https://www.facebook.com/EverydayPowerOfficial/" property="article:publisher"/>
#  <meta content="https://cdn.everydaypower.com/wp-content/uploads/2018/11/50-Jaden-Smith-Quotes-That-Expand-Your-Mindset.jpg" property="og:image"/>
#  <meta content="1000" property="og:image:width"/>
#  <meta content="667" property="og:image:height"/>
#  <meta content="2019-05-05T13:57:35-04:00" property="article:published_time"/>
#  <meta content="2020-06-30T14:29:12-04:00" property="article:modified_time"/>
#  <meta content="1923155921341058" property="fb:app_id"/>
#  <meta content="summary" name="twitter:card"/>
#  <meta content="50 Jaden Smith Quotes That Expand Your Mindset (2019)" name="twitter:title"/>
#  <meta content="Looking for the best Jaden Smith quotes? Check out our collection of quotes from the young rapper and actor that'll expand your mindset." name="twitter:description"/>
#  <meta content="https://cdn.everydaypower.com/wp-content/uploads/2018/11/50-Jaden-Smith-Quotes-That-Expand-Your-Mindset.jpg" name="twitter:image:src"/>
#  <style id="aoatfcss" media="all">
#   .ss-inline-share-wrapper .ss-social-icons-container>li>a,.ss-popup-overlay .ss-copy-action .ss-button,.ss-popup-overlay .ss-popup .ss-close-modal{border:0;text-shadow:none;-webkit-box-shadow:none;box-shadow:none;outline:0;text-decoration:none;text-transform:none;letter-spacing:0}.ss-social-icons-container>li>a:after{outline:0;content:"";background-color:transparent;position:absolute;top:0;left:0;right:0;bottom:0;z-index:1}.ss-svg-icon{height:16px;width:auto;vertical-align:text-bottom;fill:currentColor}.ss-facebook-color{background-color:#3b5998}.ss-twitter-color{background-color:#1da1f2}.ss-linkedin-color{background-color:#0077b5}.ss-inline-share-wrapper{display:block;margin:25px 0;clear:both;font-family:-apple-system,BlinkMacSystemFont,segoe ui,Roboto,Oxygen-Sans,Ubuntu,Cantarell,Arial,helvetica neue,sans-serif}.ss-inline-share-wrapper .ss-inline-share-content{display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-font-smoothing:initial}.ss-inline-share-wrapper .ss-social-icons-container{display:inline-block;padding:0!important}.ss-inline-share-wrapper .ss-social-icons-container .ss-share-network-content{height:inherit;line-height:inherit;vertical-align:middle;display:-webkit-inline-box;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-ms-flex-wrap:nowrap;flex-wrap:nowrap}.ss-inline-share-wrapper .ss-social-icons-container .ss-share-network-content i{margin-top:0;line-height:inherit;float:left}.ss-popup-overlay{display:none;font-family:-apple-system,BlinkMacSystemFont,segoe ui,Roboto,Oxygen-Sans,Ubuntu,Cantarell,Arial,helvetica neue,sans-serif;-webkit-font-smoothing:initial;content:"";position:fixed;top:0;bottom:0;left:0;right:0;z-index:99999;background:rgba(202,202,202,.75);opacity:0}.ss-popup-overlay .ss-copy-action{position:relative;display:none}.ss-popup-overlay .ss-copy-action .ss-copy-action-field{border:1px solid rgba(0,0,0,.1);border-radius:2px;color:#323b43;font-family:inherit;font-size:16px;-webkit-box-sizing:border-box;box-sizing:border-box;width:100%;height:48px!important;line-height:48px!important;padding:0 120px 0 50px!important;text-shadow:none;-webkit-box-shadow:none;box-shadow:none;outline:0;background-color:#fff;margin:0}.ss-popup-overlay .ss-copy-action .ss-button{font-weight:400;font-family:inherit;position:absolute;right:6px;top:5px;background-color:#557ceb;color:#fff;padding:0;line-height:38px;height:38px;width:105px;font-size:16px;z-index:9;border-radius:2px}.ss-popup-overlay .ss-copy-action svg{position:absolute;height:24px;width:24px;top:50%;left:15px;margin-top:-12px;fill:#dadada}.ss-popup-overlay .ss-popup{opacity:0;border-radius:2px;max-width:90%;max-height:90%;width:720px;height:auto}.ss-popup-overlay .ss-popup .ss-popup-heading{display:block;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;font-weight:300;color:#323b43;background-color:#fff;line-height:58px;height:58px;padding:0 0 0 24px;margin:0;border-top-left-radius:4px;border-top-right-radius:4px}.ss-popup-overlay .ss-popup .ss-close-modal{margin-left:auto;padding:0 24px;height:100%;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#a9a9a9}.ss-popup-overlay .ss-popup .ss-close-modal svg{width:16px;height:16px}.ss-popup-overlay .ss-popup .ss-popup-content{position:relative;top:3px;left:0;right:0;bottom:0;max-height:70vh;background-color:#fff;overflow-y:scroll;padding:24px 24px 20px;border-bottom-left-radius:4px;border-bottom-right-radius:4px}.ss-popup-overlay .ss-popup .ss-powered-by{margin-top:12px;font-size:12px;text-align:center;color:#aaa;width:100%}.ss-popup-overlay .ss-popup .ss-powered-by a{color:#557ceb}.ss-popup-overlay .s ...
#  </style>
#  <link href="//cdn.everydaypower.com/wp-content/cache/autoptimize/css/autoptimize_6e50fbe5db76645733204abbb7539312.css" media="print" onload="this.onload=null;this.media='all';" rel="stylesheet"/>
#  <body>
#   <noscript id="aonoscrcss">
#    <link href="//cdn.everydaypower.com/wp-content/cache/autoptimize/css/autoptimize_6e50fbe5db76645733204abbb7539312.css" media="all" rel="stylesheet"/>
#   </noscript>
#   <title>
#    50 Jaden Smith Quotes That Expand Your Mindset (2019)
#   </title>
#   <meta content="Looking for the best Jaden Smith quotes? Check out our collection of quotes from the young rapper and actor that'll expand your mindset." name="description"/>
#   <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
#   <link href="https://everydaypower.com/jaden-smith-quotes/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="50 Jaden Smith Quotes That Expand Your Mindset (2019)" property="og:title"/>
#   <meta content="Looking for the best Jaden Smith quotes? Check out our collection of quotes from the young rapper and actor that'll expand your mindset." property="og:description"/>
#   <meta content="https://everydaypower.com/jaden-smith-quotes/" property="og:url"/>
#   <meta content="Everyday Power" property="og:site_name"/>
#   <meta content="https://www.facebook.com/EverydayPowerOfficial/" property="article:publisher"/>
#   <meta content="2019-05-05T17:57:35+00:00" property="article:published_time"/>
#   <meta content="2020-06-30T18:29:12+00:00" property="article:modified_time"/>
#   <meta content="https://cdn.everydaypower.com/wp-content/uploads/2018/11/50-Jaden-Smith-Quotes-That-Expand-Your-Mindset.jpg" property="og:image"/>
#   <meta content="1000" property="og:image:width"/>
#   <meta content="667" property="og:image:height"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@EverydayPower__" name="twitter:creator"/>
#   <meta content="@EverydayPower__" name="twitter:site"/>
#   <link href="//scripts.mediavine.com" rel="dns-prefetch"/>
#   <link href="//cdn.everydaypower.com" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <script async="async" data-cfasync="false" data-noptimize="1" src="https://scripts.mediavine.com/tags/everyday-power.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.everydaypower.com/wp-includes/js/jquery/jquery.js" type="text/javascript">
#   </script>
#   <link as="font" crossorigin="" href="https://cdn.everydaypower.com/wp-content/themes/zox-news/fonts/montserrat-v14-latin-regular.woff2" rel="preload"/>
#   <link as="font" crossorigin="" href="https://cdn.everydaypower.com/wp-content/themes/zox-news/font-awesome/fonts/fontawesome-webfont.woff2?v=4.6.3" rel="preload"/>
#   <script type="text/javascript">
#    //     jQuery(function($) {
# //         var allTexts = [
# //             'Love Your <span>Full Self</span>',
# //             'Dream <span>Big</span>',
# //             'Live <span>Fully</span>',
# //             'You <span>Matter</span>',
# //             'Celebrate The <span>Good</span>',
# //             'Conquer From <span>Within</span>',
# //             'Make Yourself <span>Proud</span>',
# //             'Love Always <span>Win</span>',
# //             'Never Stop <span>Learning</span>',
# //             'Keep Moving <span>Forward</span>',
# //             'Embrace The <span>Journey</span>',
# //             'Love Each <span>Other</span>',
# //             'You Are <span>Loved</span>',
# //             'Dare To <span>Begin</span>',
# //             'You Got <span>This</span>',
# //             'Take Your <span>Time</span>',
# //             'Everything <span>Connects</span>',
# //             'Enjoy The <span>Moment</span>',
# //             'Just Be <span>You</span>',
# //             'Your Story <span>Matters</span>',
# //             'Be The <span>Change</span>',
# //             'Never Stop <span>Dreaming</span>',
# //             'Defy The <span>Odds</span>',
# //             'Be The <span>Exception</span>',
# //             'Enjoy Your <span>Life</span>',
# //             'Why Not <span>Now?</span>',
# //             'Dwell In <span>Hope</span>',
# //             'We\'re Better <span>Together</span>',
# //             'Let <span>Love In</span>',
# //             'Kindness Is <span>Magic</span>',
# //             'You Are <span>Enough</span>',
# //             'Kindness Is <span>Free</span>',
# //             'Stronger Than <span>Yesterday</span>',
# //             'Radiate Positive <span>Vibes</span>',
# //             'Good Vibes <span>Only</span>'
# //         ];
# //         var text = allTexts[Math.floor(Math.random() * allTexts.length)];
#
# //         document.getElementById("rt_txt1").innerHTML = text;
#
# //         function delete_rand_text_block() {
# //             jQuery("#random_text_block").fadeOut(400, function () {
# //                 jQuery(this).remove();
# //             });
# //         }
#
# //         setTimeout(delete_rand_text_block, 1200);
#
# //     });
#   </script>
#   <div id="mvp-fly-wrap">
#    <div class="left relative" id="mvp-fly-menu-top">
#     <div class="mvp-fly-top-out left relative">
#      <div class="mvp-fly-top-in">
#       <div class="left relative" id="mvp-fly-logo">
#        <a href="https://everydaypower.com/">
#         <img alt="Everyday Power" data-rjs="2" src="https://cdn.everydaypower.com/wp-content/uploads/2018/07/Everydaypower_logo_black-1.png" style="margin-top: 0.75rem; max-width: 10rem !important; height: auto !important;"/>
#        </a>
#       </div>
#      </div>
#      <div class="mvp-fly-but-wrap mvp-fly-but-menu mvp-fly-but-click">
#       <span>
#       </span>
#       <span>
#       </span>
#       <span>
#       </span>
#       <span>
#       </span>
#      </div>
#     </div>
#    </div>
#    <div id="mvp-fly-menu-wrap">
#     <nav class="mvp-fly-nav-menu left relative">
#      <div class="menu-new-nerd-menu-container">
#       <ul class="menu" id="menu-new-nerd-menu">
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-113056" id="menu-item-113056">
#         <a href="https://everydaypower.com/">
#          Home
#         </a>
#        </li>
#        <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-has-children menu-item-77480" id="menu-item-77480">
#         <a href="https://everydaypower.com/category/inspirational-quotes/">
#          Quotes
#         </a>
#         <ul class="sub-menu">
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-97359" id="menu-item-97359">
#           <a href="https://everydaypower.com/monday-motivation-quotes/">
#            Monday Motivation Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-97361" id="menu-item-97361">
#           <a href="https://everydaypower.com/anxiety-quotes/">
#            Anxiety Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-97357" id="menu-item-97357">
#           <a href="https://everydaypower.com/best-fitness-motivational-quotes/">
#            Gym &amp; Fitness Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-97358" id="menu-item-97358">
#           <a href="https://everydaypower.com/addiction-quotes/">
#            Recovery and Addiction Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-95476" id="menu-item-95476">
#           <a href="https://everydaypower.com/happy-birthday-quotes-for-a-friend/">
#            Happy Birthday Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-95477" id="menu-item-95477">
#           <a href="https://everydaypower.com/deep-love-quotes/">
#            Love Quotes
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-113054" id="menu-item-113054">
#           <a href="https://everydaypower.com/books-for-athletes-must-read/">
#            Books for Athletes
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-home menu-item-has-children menu-item-77551" id="menu-item-77551">
#         <a href="https://everydaypower.com/#">
#          More Articles
#         </a>
#         <ul class="sub-menu">
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77562" id="menu-item-77562">
#           <a href="https://everydaypower.com/category/relationships/">
#            Relationships
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77553" id="menu-item-77553">
#           <a href="https://everydaypower.com/category/entrepreneurship/">
#            Entrepreneurship
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77554" id="menu-item-77554">
#           <a href="https://everydaypower.com/category/good-news/">
#            Good News
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77555" id="menu-item-77555">
#           <a href="https://everydaypower.com/category/health/">
#            Health
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77556" id="menu-item-77556">
#           <a href="https://everydaypower.com/category/interviews/">
#            Interviews and Podcasts on Everyday Power
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77557" id="menu-item-77557">
#           <a href="https://everydaypower.com/category/life/">
#            Life Advice and Skills
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77559" id="menu-item-77559">
#           <a href="https://everydaypower.com/category/money/">
#            Money
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77560" id="menu-item-77560">
#           <a href="https://everydaypower.com/category/motivational-videos/">
#            Motivational Videos
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77561" id="menu-item-77561">
#           <a href="https://everydaypower.com/category/parenting/">
#            Parenting
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77563" id="menu-item-77563">
#           <a href="https://everydaypower.com/category/travel/">
#            Travel
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </div>
#     </nav>
#    </div>
#    <div id="mvp-fly-soc-wrap">
#     <span class="mvp-fly-soc-head">
#      Connect with us
#     </span>
#     <ul class="mvp-fly-soc-list left relative">
#      <li>
#       <a class="fa fa-facebook fa-2" href="https://www.facebook.com/EverydayPowerOfficial/" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="fa fa-twitter fa-2" href="https://twitter.com/JeffMoore__" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="fa fa-pinterest-p fa-2" href="https://www.pinterest.com/RealEverydayPower/" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="fa fa-instagram fa-2" href="https://www.instagram.com/everydaypowerofficial/" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="fa fa-youtube-play fa-2" href="https://www.youtube.com/user/MooreEverydayPower/" target="_blank">
#       </a>
#      </li>
#      <li>
#       <a class="fa fa-linkedin fa-2" href="https://www.linkedin.com/company/everyday-power" target="_blank">
#       </a>
#      </li>
#     </ul>
#    </div>
#   </div>
#   <div class="left relative" id="mvp-site">
#    <div id="mvp-search-wrap">
#     <div id="mvp-search-box">
#      <form action="https://everydaypower.com/" id="searchform" method="get">
#       <input id="s" name="s" onblur='if (this.value == "") { this.value = "Search"; }' onfocus='if (this.value == "Search") { this.value = ""; }' type="text" value="Search"/>
#       <input id="searchsubmit" type="hidden" value="Search"/>
#      </form>
#     </div>
#     <div class="mvp-search-but-wrap mvp-search-click">
#      <span>
#      </span>
#      <span>
#      </span>
#     </div>
#    </div>
#    <div class="left relative" id="mvp-site-wall">
#     <div class="left relative" id="mvp-site-main">
#      <header class="left relative" id="mvp-main-head-wrap">
#       <nav class="left relative" id="mvp-main-nav-wrap">
#        <div class="left relative" id="mvp-main-nav-small">
#         <div class="left" id="mvp-main-nav-small-cont">
#          <div class="mvp-main-box">
#           <div id="mvp-nav-small-wrap">
#            <div class="mvp-nav-small-right-out left">
#             <div class="mvp-nav-small-right-in">
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://everydaypower.com/you-are-my-sunshine-quotes/">
#                         30 You Are My Sunshine Quotes about Love and Friendship
#                        </a>
#                       </li>
#                       <li>
#                        <a href="https://everydaypower.com/franklin-roosevelt-quotes/">
#                         50 Franklin Roosevelt Quotes That Encourage Progress
#                        </a>
#                       </li>
#                      </ul>
#                     </section>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </article>
#         </div>
#         <footer class="left relative" id="mvp-foot-wrap">
#          <div class="left relative" id="mvp-foot-top">
#           <div class="mvp-main-box">
#            <div class="left relative" id="mvp-foot-logo">
#             <a href="https://everydaypower.com/">
#              <noscript>
#               <img alt="Everyday Power" data-rjs="2" src="https://cdn.everydaypower.com/wp-content/uploads/2018/05/Everyday-Power-Logo-Black-Motivational-quotes-about-life.png" style="max-width: 15rem;"/>
#              </noscript>
#              <img alt="Everyday Power" class="lazyload" data-rjs="2" data-src="https://cdn.everydaypower.com/wp-content/uploads/2018/05/Everyday-Power-Logo-Black-Motivational-quotes-about-life.png" src="data:image/svg+xml,%3Csvg%20xmlns=%22http://www.w3.org/2000/svg%22%20viewBox=%220%200%20210%20140%22%3E%3C/svg%3E" style="max-width: 15rem;"/>
#             </a>
#            </div>
#            <div class="left relative" id="mvp-foot-soc">
#             <ul class="mvp-foot-soc-list left relative">
#              <li>
#               <a class="fa fa-facebook fa-2" href="https://www.facebook.com/EverydayPowerOfficial/" target="_blank">
#               </a>
#              </li>
#              <li>
#               <a class="fa fa-twitter fa-2" href="https://twitter.com/JeffMoore__" target="_blank">
#               </a>
#              </li>
#              <li>
#               <a class="fa fa-pinterest-p fa-2" href="https://www.pinterest.com/RealEverydayPower/" target="_blank">
#               </a>
#              </li>
#              <li>
#               <a class="fa fa-instagram fa-2" href="https://www.instagram.com/everydaypowerofficial/" target="_blank">
#               </a>
#              </li>
#              <li>
#               <a class="fa fa-youtube-play fa-2" href="https://www.youtube.com/user/MooreEverydayPower/" target="_blank">
#               </a>
#              </li>
#              <li>
#               <a class="fa fa-linkedin fa-2" href="https://www.linkedin.com/company/everyday-power" target="_blank">
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="left relative" id="mvp-foot-menu-wrap">
#             <div class="left relative" id="mvp-foot-menu">
#              <div class="menu-footer-menu-container">
#               <ul class="menu" id="menu-footer-menu">
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56156" id="menu-item-56156">
#                 <a href="https://everydaypower.com/about-us/">
#                  About Us
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56157" id="menu-item-56157">
#                 <a href="https://everydaypower.com/advertise-with-us/">
#                  Advertise
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-58924" id="menu-item-58924">
#                 <a href="https://everydaypower.com/sitemap_index.xml">
#                  Sitemap
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56159" id="menu-item-56159">
#                 <a href="https://everydaypower.com/contact-us/">
#                  Contact Us
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56160" id="menu-item-56160">
#                 <a href="https://everydaypower.com/write-for-us/">
#                  Write For Us
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56162" id="menu-item-56162">
#                 <a href="https://everydaypower.com/privacy-policy/">
#                  Privacy Policy
#                 </a>
#                </li>
#                <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-56163" id="menu-item-56163">
#                 <a href="https://everydaypower.com/terms-of-use/">
#                  Terms of Service
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="left relative" id="mvp-foot-bot">
#           <div class="mvp-main-box">
#            <div class="left relative" id="mvp-foot-copy">
#             <p>
#              EverydayPower.com © 2013 - 2020
#             </p>
#            </div>
#           </div>
#          </div>
#         </footer>
#        </div>
#       </nav>
#      </header>
#     </div>
#    </div>
#    <div class="mvp-fly-fade mvp-fly-but-click">
#    </div>
#    <div data-theiastickysidebar-options='{"containerSelector":"#mvp-main-body-wrap","additionalMarginTop":100,"additionalMarginBottom":0,"updateSidebarHeight":false,"minWidth":0,"sidebarBehavior":"modern","disableOnResponsiveLayouts":true}' data-theiastickysidebar-sidebarselector='".mvp-post-soc-wrap.left"'>
#    </div>
#    <noscript>
#     <style>
#      .lazyload{display:none;}
#     </style>
#    </noscript>
#    <script data-noptimize="1">
#     window.lazySizesConfig=window.lazySizesConfig||{};window.lazySizesConfig.loadMode=1;
#    </script>
#    <script async="" data-noptimize="1" src="//cdn.everydaypower.com/wp-content/plugins/autoptimize/classes/external/js/lazysizes.min.js?ao_version=2.8.1">
#    </script>
#    <script type="text/javascript">
#     /* <![CDATA[ */ var socialsnap_script = {"ajaxurl":"https:\/\/everydaypower.com\/wp-admin\/admin-ajax.php","on_media_width":"250","on_media_height":"250","nonce":"42972f2303","post_id":"78944","click_tracking":""}; /* ]]> */
#    </script>
#    <script type="text/javascript">
#     jQuery(document).ready(function($) {
# 	$(window).load(function(){
# 	var leaderHeight = $("#mvp-leader-wrap").outerHeight();
# 	var navHeight = $("#mvp-main-head-wrap").outerHeight();
# 	var headerHeight = navHeight + leaderHeight;
# 	var previousScroll = 0;
# 	$(window).scroll(function(event){
# 			var scroll = $(this).scrollTop();
# 			if ($(window).scrollTop() > headerHeight){
# 				$("#mvp-main-nav-small").addClass("mvp-nav-small-fixed");
# 				$("#mvp-main-body-wrap").css("margin-top", navHeight );
# 			} else {
# 				$("#mvp-main-nav-small").removeClass("mvp-nav-small-fixed");
# 				$("#mvp-main-body-wrap").css("margin-top","0");
# 			}
# 			if ($(window).scrollTop() > headerHeight + 50){
# 				$("#mvp-main-nav-small").addClass("mvp-fixed");
# 				$("#mvp-main-nav-small").addClass("mvp-fixed-shadow");
# 				$(".mvp-fly-top").addClass("mvp-to-top");
# 	    		if(scroll < previousScroll) {
# 					$("#mvp-main-nav-small").removeClass("mvp-soc-mob-up");
# 					$("#mvp-soc-mob-wrap").removeClass("mvp-soc-mob-up");
# 					$(".mvp-drop-nav-title").removeClass("mvp-nav-small-post");
# 					$(".mvp-nav-menu").show();
# 				} else {
# 					$("#mvp-main-nav-small").addClass("mvp-soc-mob-up");
# 					$("#mvp-soc-mob-wrap").addClass("mvp-soc-mob-up");
# 					$(".mvp-drop-nav-title").addClass("mvp-nav-small-post");
# 					$(".mvp-nav-menu").hide();
# 				}
# 			} else {
# 				$("#mvp-main-nav-small").removeClass("mvp-fixed");
# 				$("#mvp-main-nav-small").removeClass("mvp-fixed-shadow");
# 	    		$(".mvp-fly-top").removeClass("mvp-to-top");
# 			}
# 			previousScroll = scroll;
# 	});
# 	});
# 	});
#
#
# 	jQuery(document).ready(function($) {
# 	// Video Post Scroll
# 	$(window).on("scroll.video", function(event){
# 		var scrollTop     = $(window).scrollTop();
#     	var elementOffset = $("#mvp-content-wrap").offset().top;
#     	var distance      = (elementOffset - scrollTop);
# 		var aboveHeight = $("#mvp-video-embed-wrap").outerHeight();
# 		if ($(window).scrollTop() > distance + aboveHeight + screen.height){
# 			$("#mvp-video-embed-cont").addClass("mvp-vid-fixed");
# 			$("#mvp-video-embed-wrap").addClass("mvp-vid-height");
# 			$(".mvp-video-close").show();
# 		} else {
# 			$("#mvp-video-embed-cont").removeClass("mvp-vid-fixed");
# 			$("#mvp-video-embed-wrap").removeClass("mvp-vid-height");
# 			$(".mvp-video-close").hide();
# 		}
# 	});
#
#  	$(".mvp-video-close").on("click", function(){
# 		$("iframe").attr("src", $("iframe").attr("src"));
# 		$("#mvp-video-embed-cont").removeClass("mvp-vid-fixed");
# 		$("#mvp-video-embed-wrap").removeClass("mvp-vid-height");
# 		$(".mvp-video-close").hide();
# 		$(window).off("scroll.video");
#   	});
#
# 	});
#
#
# 	jQuery(document).ready(function($) {
# 	$(".menu-item-has-children a").click(function(event){
# 	  event.stopPropagation();
# 	  location.href = this.href;
#   	});
#
# 	$(".menu-item-has-children").click(function(){
#     	  $(this).addClass("toggled");
#     	  if($(".menu-item-has-children").hasClass("toggled"))
#     	  {
#     	  $(this).children("ul").toggle();
# 	  $(".mvp-fly-nav-menu").getNiceScroll().resize();
# 	  }
# 	  $(this).toggleClass("tog-minus");
#     	  return false;
#   	});
#
# 	// Main Menu Scroll
# 	$(window).load(function(){
# 	  $(".mvp-fly-nav-menu").niceScroll({cursorcolor:"#888",cursorwidth: 7,cursorborder: 0,zindex:999999});
# 	});
# 	});
#
#
# 	jQuery(document).ready(function($) {
# 	$(".infinite-content").infiniteScroll({
# 	  path: ".inactive",
# 	  append: ".mvp-blog-story-col",
# 	  loadOnScroll: true,
# 	  scrollThreshold: 500,
# 	  debug: true,
# 	  button: ".mvp-inf-more-but",
# 	});
# 	$(window).load(function(){
# 		if ($(".mvp-nav-links a").length) {
# 			$(".mvp-inf-more-but").css("display","inline-block");
# 		} else {
# 			$(".mvp-inf-more-but").css("display","none");
# 		}
# 	});
# 	});
#    </script>
#    <div class="ss-popup-overlay" id="ss-copy-popup">
#     <div class="ss-popup">
#      <div class="ss-popup-heading">
#       <span>
#        Copy link
#       </span>
#       <a class="ss-close-modal" href="#" id="" rel="nofollow noopener">
#        <svg aria-hidden="true" class="ss-svg-icon" focusable="false" height="32" role="img" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#         <path d="M17.883 16.667l7.058-7.058c0.517-0.517 0.517-1.367 0-1.883s-1.367-0.517-1.883 0l-7.058 7.058-7.058-7.058c-0.517-0.517-1.367-0.517-1.883 0s-0.517 1.367 0 1.883l7.058 7.058-7.058 7.058c-0.517 0.517-0.517 1.367 0 1.883 0.258 0.258 0.6 0.392 0.942 0.392s0.683-0.133 0.942-0.392l7.058-7.058 7.058 7.058c0.258 0.258 0.6 0.392 0.942 0.392s0.683-0.133 0.942-0.392c0.517-0.517 0.517-1.367 0-1.883l-7.058-7.058z">
#         </path>
#        </svg>
#       </a>
#      </div>
#      <div class="ss-popup-content">
#       <div class="ss-copy-action">
#        <input aria-label="Copy" class="ss-copy-action-field" readonly="readonly" type="text" value="https://everydaypower.com/jaden-smith-quotes/"/>
#        <a class="ss-button" href="#" rel="nofollow noopener">
#         Copy
#         <span class="ss-share-network-tooltip">
#          Copied
#         </span>
#        </a>
#        <svg aria-hidden="true" class="ss-svg-icon" focusable="false" height="32" role="img" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
#         <path d="M25.313 28v-18.688h-14.625v18.688h14.625zM25.313 6.688c1.438 0 2.688 1.188 2.688 2.625v18.688c0 1.438-1.25 2.688-2.688 2.688h-14.625c-1.438 0-2.688-1.25-2.688-2.688v-18.688c0-1.438 1.25-2.625 2.688-2.625h14.625zM21.313 1.313v2.688h-16v18.688h-2.625v-18.688c0-1.438 1.188-2.688 2.625-2.688h16z">
#         </path>
#        </svg>
#       </div>
#       <div class="ss-powered-by">
#        Powered by
#        <a href="https://socialsnap.com/?utm_source=WordPress&amp;utm_medium=link&amp;utm_campaign=inthewild" rel="nofollow noopener" target="_blank">
#         <svg aria-hidden="true" class="ss-svg-icon" focusable="false" height="32" role="img" viewbox="0 0 30 32" width="30" xmlns="http://www.w3.org/2000/svg">
#          <path d="M22.293 0.146l7.602 4.172c0.386 0.201 0.386 0.541 0 0.757l-16.688 9.147c-1.684 0.943-2.241 2.271-1.669 3.461 0 0.093 0 0.201-0.201 0.263-0.207 0.088-0.441 0.088-0.649 0l-10.399-5.702c-0.386-0.201-0.386-0.541 0-0.757l20.628-11.311c0.428-0.225 0.937-0.236 1.375-0.031zM7.892 31.854l-7.602-4.172c-0.386-0.201-0.386-0.541 0-0.757l16.688-9.147c1.684-0.943 2.241-2.271 1.669-3.461 0-0.093 0-0.201 0.201-0.263 0.207-0.088 0.442-0.088 0.649 0l10.399 5.702c0.386 0.201 0.386 0.541 0 0.757l-20.628 11.311c-0.428 0.225-0.937 0.237-1.375 0.031z">
#          </path>
#         </svg>
#         Social Snap
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     var SocialSnapURL 				= window.location.href;
# 			var SocialSnapShareCacheExpired = 0;
# 			var SocialSnapShareNetworks     = ["facebook","twitter","linkedin"];
#
# 			if ( -1 !== SocialSnapURL.indexOf('ss_cache_refresh') ) {
#
# 				SocialSnapShareCacheExpired = true;
#
# 			} else {
#
# 				var SocialSnapServerTimestamp 	= 1609400176;
# 				var SocialSnapBrowserTimestamp 	= Date.now();
#
# 				if ( ! SocialSnapBrowserTimestamp ) {
# 					SocialSnapBrowserTimestamp = new Date().getTime();
# 				}
#
# 				SocialSnapBrowserTimestamp = Math.floor( SocialSnapBrowserTimestamp / 1000 );
#
# 				SocialSnapShareCacheExpired = SocialSnapShareCacheExpired && ( SocialSnapBrowserTimestamp - SocialSnapServerTimestamp < 60 );
# 			}
#    </script>
#    <script>
#     jQuery('#menu-main-menu').hover(function(){
# 	jQuery('#menu-main-menu img').each(function(key, value){
# 		jQuery(value).attr('src', jQuery(value).attr('data-src'));
# 		jQuery(value).removeClass('lazy-hidden');
# 		jQuery(value).addClass('lazy-loaded');
# 	});
# });
#    </script>
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MLQRSLV" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#    <script defer="" src="//cdn.everydaypower.com/wp-content/cache/autoptimize/js/autoptimize_12150ec9c39310ff986c5fb2c0d06a61.js">
#    </script>
#   </div>
#  </body>
# </html>

# %%
headers = soup.find_all("p")
quotes = []
for s in headers:
    #print(s.string)
    try:
        print(s.string)
        quotes.append(re.match(s.get_text(), r"(<p>)\d+").string)
    except Exception as e:
        print(s.get_text())
        print(e)

print("quotes:")
print(quotes)
# Out:
# Never let anyone else’s light overshadow you. Read these Jaden Smith quotes to find out how.
# Never let anyone else’s light overshadow you. Read these Jaden Smith quotes to find out how.
# 'NoneType' object has no attribute 'string'
# By
# By
# 'NoneType' object has no attribute 'string'
# Our latest collection of Jaden Smith quotes on Everyday Power Blog.
# Our latest collection of Jaden Smith quotes on Everyday Power Blog.
# 'NoneType' object has no attribute 'string'
# None
# Jaden Smith is an American rapper, singer and actor best known for appearing in movies such as “The Pursuit of Happyness”, “The Karate Kid” and “After Earth”.
# 'NoneType' object has no attribute 'string'
# None
# Besides acting, Smith is a talented musician and has interests in business as well. After some performances with popular singers like Justin Bieber and releasing a couple of mixtapes, he released his debut studio album, “Syre”, in 2017 and later followed up with “Syre: The Electric Album” in 2018.
# 'NoneType' object has no attribute 'string'
# Smith has also been a youth ambassador for Project Zambi, which offers assistance for Zambian children orphaned by AIDS.
# Smith has also been a youth ambassador for Project Zambi, which offers assistance for Zambian children orphaned by AIDS.
# 'NoneType' object has no attribute 'string'
# None
# A child of two very famous Hollywood stars, Smith has not let his parents overshadow his young career. In that respect, here are some thought-provoking Jaden Smith quotes that will expand your mindset.
# 'NoneType' object has no attribute 'string'
# None
# 1. “If newborn babies could speak they would be the most intelligent beings on planet earth.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 2. “The Moment That Truth Is Organized It Becomes A Lie.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# None
# 3. “Instagram is not the answer.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 4. “You can discover everything you need to know about everything by looking at your hands.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 5. “No one believed Galileo either.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 6. “Being born was the most influential thing that’s ever happened to me, for myself.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 7. “When Life Gives You Big Problems, Just Be Happy You Forgot All Your Little Problems.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 8. “I’ll never read every single book or go to every single place. But I’ll die in the trying of it.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 9. “The only way to change something is to shock it. If you want your muscles to grow, you have to shock them. If you want society to change, you have to shock them.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 10. “I feel like a serious revolution needs to take place in order for human beings to evolve in a way where we can truly exist as a society.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 11. “If a cupcake falls from a tree how far away will it be from down.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 12. “They Distract You With Us So You Don’t Pay Attention To The Missing Girls In Nigeria.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# None
# 13. “We Need To Stop Teaching The Youth About The Past And Encourage Them To Change The Future.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 14. “What is the definition of ‘light’?” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 15. “Unawareness Is The Only Sin, And If You Were Aware You Would Know.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 16. “Trees are never sad look at them every once in a while they’re quite beautiful.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 17. “Since we’re family, we both have wins, and we don’t really go against each other, like, ‘I’m gonna kill you,’ ” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 18. “People Use To Ask Me What Do You Wanna Be When You Get Older And I Would Say What A Stupid Question The Real Question Is What Am I Right Now.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
# 19. “People Think A RelationShip Makes You Whole, That It’s Two 50%’s Coming Together To Make 100% When It Should Be Two 100%’s Making 200%.” – Jaden Smith
# 'NoneType' object has no attribute 'string'
# None
#
# 'NoneType' object has no attribute 'string'
# None
#  Bert
# 'NoneType' object has no attribute 'string'
#  August 18, 2020 at 8:46 PM
#  August 18, 2020 at 8:46 PM
# 'NoneType' object has no attribute 'string'
# Jordan! My mannnnnnn. This shit is tight. I can’t believe my whole life never hearing it before. I am new. I am changrd. Catch me on the mountain. I’m a monk. Thank u my brother
# Jordan! My mannnnnnn. This shit is tight. I can’t believe my whole life never hearing it before. I am new. I am changrd. Catch me on the mountain. I’m a monk. Thank u my brother
# 'NoneType' object has no attribute 'string'
# None
#  Emmanuel
# 'NoneType' object has no attribute 'string'
#  March 27, 2019 at 5:51 PM
#  March 27, 2019 at 5:51 PM
# 'NoneType' object has no attribute 'string'
# Hayden bro I love your music it helps me grow.syre
# Hayden bro I love your music it helps me grow.syre
# 'NoneType' object has no attribute 'string'
# None
#  Keineetse Leshona
# 'NoneType' object has no attribute 'string'
#  January 3, 2019 at 9:22 AM
#  January 3, 2019 at 9:22 AM
# 'NoneType' object has no attribute 'string'
# People tell me to smile but “I tell the lack of emotion in my face doesn’t mean that I’m unhappy”. I so love this quote because it just answers all the people who feel one has to smile in order to show their love and appreciation even when they don’t feel like it
# People tell me to smile but “I tell the lack of emotion in my face doesn’t mean that I’m unhappy”. I so love this quote because it just answers all the people who feel one has to smile in order to show their love and appreciation even when they don’t feel like it
# 'NoneType' object has no attribute 'string'
# None
#  Jeffrey I. Moore
# 'NoneType' object has no attribute 'string'
#  January 5, 2019 at 12:13 AM
#  January 5, 2019 at 12:13 AM
# 'NoneType' object has no attribute 'string'
# Haha, YES!!
# Haha, YES!!
# 'NoneType' object has no attribute 'string'
# None
# Your email address will not be published. Required fields are marked *
# 'NoneType' object has no attribute 'string'
# None
# Comment
# 'NoneType' object has no attribute 'string'
# None
# Name *
# 'NoneType' object has no attribute 'string'
# None
# Email *
# 'NoneType' object has no attribute 'string'
# None
#
# 'NoneType' object has no attribute 'string'
# None
# None
# 30 Kevin Hart quotes on Success, Family and Work Ethic
# 30 Kevin Hart quotes on Success, Family and Work Ethic
# 'NoneType' object has no attribute 'string'
# 50 Aretha Franklin Quotes about Love, Life and Respect
# 50 Aretha Franklin Quotes about Love, Life and Respect
# 'NoneType' object has no attribute 'string'
# 50 Balanced Compromise Quotes to Help You Negotiate a Win
# 50 Balanced Compromise Quotes to Help You Negotiate a Win
# 'NoneType' object has no attribute 'string'
# 30 You Are My Sunshine Quotes about Love and Friendship
# 30 You Are My Sunshine Quotes about Love and Friendship
# 'NoneType' object has no attribute 'string'
# 50 Franklin Roosevelt Quotes That Encourage Progress
# 50 Franklin Roosevelt Quotes That Encourage Progress
# 'NoneType' object has no attribute 'string'
# 50 Unexpected Quotes to Prepare You for the Unforeseen
# 50 Unexpected Quotes to Prepare You for the Unforeseen
# 'NoneType' object has no attribute 'string'
# 50 Blame Quotes on How To Stop Playing the Blame Game
# 50 Blame Quotes on How To Stop Playing the Blame Game
# 'NoneType' object has no attribute 'string'
# 50 Princess Leia Quotes for Star Wars Fans
# 50 Princess Leia Quotes for Star Wars Fans
# 'NoneType' object has no attribute 'string'
# 50 Surrender Quotes to Teach You When to Push On and When to Give Up
# 50 Surrender Quotes to Teach You When to Push On and When to Give Up
# 'NoneType' object has no attribute 'string'
# 50 Tiger King Quotes From the Craziest Trend of 2020
# 50 Tiger King Quotes From the Craziest Trend of 2020
# 'NoneType' object has no attribute 'string'
# 50 St Therese of Lisieux Quotes to Lift Your Spirit
# 50 St Therese of Lisieux Quotes to Lift Your Spirit
# 'NoneType' object has no attribute 'string'
# 50 Wise Rainer Maria Rilke Quotes on Life, Love, and Reflection
# 50 Wise Rainer Maria Rilke Quotes on Life, Love, and Reflection
# 'NoneType' object has no attribute 'string'
# 50 Melanie Martinez Quotes About Music and Life
# 50 Melanie Martinez Quotes About Music and Life
# 'NoneType' object has no attribute 'string'
# 50 Idea Quotes to Get the Wheels Turning
# 50 Idea Quotes to Get the Wheels Turning
# 'NoneType' object has no attribute 'string'
# 50 Balanced Compromise Quotes to Help You Negotiate a Win
# 50 Balanced Compromise Quotes to Help You Negotiate a Win
# 'NoneType' object has no attribute 'string'
# 30 You Are My Sunshine Quotes about Love and Friendship
# 30 You Are My Sunshine Quotes about Love and Friendship
# 'NoneType' object has no attribute 'string'
# 50 Franklin Roosevelt Quotes That Encourage Progress
# 50 Franklin Roosevelt Quotes That Encourage Progress
# 'NoneType' object has no attribute 'string'
# 50 Unexpected Quotes to Prepare You for the Unforeseen
# 50 Unexpected Quotes to Prepare You for the Unforeseen
# 'NoneType' object has no attribute 'string'
# 50 Blame Quotes on How To Stop Playing the Blame Game
# 50 Blame Quotes on How To Stop Playing the Blame Game
# 'NoneType' object has no attribute 'string'
# 50 Princess Leia Quotes for Star Wars Fans
# 50 Princess Leia Quotes for Star Wars Fans
# 'NoneType' object has no attribute 'string'
# 50 Surrender Quotes to Teach You When to Push On and When to Give Up
# 50 Surrender Quotes to Teach You When to Push On and When to Give Up
# 'NoneType' object has no attribute 'string'
# 50 Tiger King Quotes From the Craziest Trend of 2020
# 50 Tiger King Quotes From the Craziest Trend of 2020
# 'NoneType' object has no attribute 'string'
# 50 St Therese of Lisieux Quotes to Lift Your Spirit
# 50 St Therese of Lisieux Quotes to Lift Your Spirit
# 'NoneType' object has no attribute 'string'
# 50 Wise Rainer Maria Rilke Quotes on Life, Love, and Reflection
# 50 Wise Rainer Maria Rilke Quotes on Life, Love, and Reflection
# 'NoneType' object has no attribute 'string'
# 50 Melanie Martinez Quotes About Music and Life
# 50 Melanie Martinez Quotes About Music and Life
# 'NoneType' object has no attribute 'string'
# 50 Idea Quotes to Get the Wheels Turning
# 50 Idea Quotes to Get the Wheels Turning
# 'NoneType' object has no attribute 'string'
# EverydayPower.com © 2013 - 2020
# EverydayPower.com © 2013 - 2020
# 'NoneType' object has no attribute 'string'
# quotes:
# ['(<p>)\\d+', '(<p>)\\d+', '(<p>)\\d+', '(<p>)\\d+', '(<p>)\\d+', '(<p>)\\d+', '(<p>)\\d+']
