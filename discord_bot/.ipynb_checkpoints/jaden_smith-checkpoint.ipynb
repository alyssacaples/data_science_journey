# %%
import requests
from bs4 import BeautifulSoup as bs
import re

# %%
#get info from webpage
r = requests.get("https://everydaypower.com/jaden-smith-quotes/")

#convert to a beautiful soup object
soup = bs(r.content)

#prints out elements in a pretty way

# %%
headers = soup.find_all("p")
just_text = [text for text in soup.stripped_strings]
just_text
# Out:
# ['50 Jaden Smith Quotes That Expand Your Mindset (2019)',
#  'Home',
#  'Quotes',
#  'Monday Motivation Quotes',
#  'Anxiety Quotes',
#  'Gym & Fitness Quotes',
#  'Recovery and Addiction Quotes',
#  'Happy Birthday Quotes',
#  'Love Quotes',
#  'Good Morning Quotes and Texts',
#  'Smile Quotes',
#  'Friendship Quotes',
#  'Love Quotes for Him',
#  'Instagram Bio Quotes',
#  'Best Rap Quotes',
#  'Sad Love Quotes',
#  'Famous Quotes',
#  'Love Yourself Quotes',
#  'Quotes About Education',
#  'Depression Quotes',
#  'Top Reads',
#  'Get Your Hustle On',
#  'Chasing Your Dreams',
#  'Around Positive People',
#  'Get Core Confidence',
#  'Your Mission Statement',
#  'How to Wake Up Ready',
#  'How To Be More Confident',
#  'Get Goal Oriented',
#  'Goals',
#  'Protect Your Vibes',
#  'Mind Blowing Questions',
#  'Remind Yourself',
#  'Purpose Leads To Results',
#  'Fulfill Your Dreams',
#  'When You’re Overwhelmed',
#  'Stand Up',
#  'Stop Expecting from Others',
#  'Before You Go To Sleep',
#  'Keeping Your Dreams',
#  'Small Minds',
#  '25 Top Rap Songs',
#  'Inspiration',
#  'Become Happier',
#  'Before You Quit',
#  'Your Life Summed Up',
#  '2 Hours a Day',
#  'Wasting Time on Facebook',
#  'How To Deal With Regret',
#  'Loneliness Into Reflection',
#  'Voices In Your Head',
#  'Erasing Bad Habits',
#  'Career',
#  'Work From Home',
#  'Lazy Vs. No Passion',
#  'Online Classes and Training',
#  'Pomodoro Technique',
#  'Online Bachelor’s Degree',
#  'Mindset',
#  'Books',
#  'Motivational Books',
#  'Books For Men',
#  'Spiritual Books',
#  'Books for Athletes',
#  'More Articles',
#  'Relationships',
#  'Entrepreneurship',
#  'Good News',
#  'Health',
#  'Interviews and Podcasts on Everyday Power',
#  'Life Advice and Skills',
#  'Money',
#  'Motivational Videos',
#  'Parenting',
#  'Travel',
#  'Connect with us',
#  'Everyday Power',
#  '50 Jaden Smith Quotes That Expand Your Mindset',
#  'Home',
#  'Quotes',
#  'Monday Motivation Quotes',
#  'Anxiety Quotes',
#  'Gym & Fitness Quotes',
#  'Recovery and Addiction Quotes',
#  'Happy Birthday Quotes',
#  'Love Quotes',
#  'Good Morning Quotes and Texts',
#  'Smile Quotes',
#  'Friendship Quotes',
#  'Love Quotes for Him',
#  'Instagram Bio Quotes',
#  'Best Rap Quotes',
#  'Sad Love Quotes',
#  'Famous Quotes',
#  'Love Yourself Quotes',
#  'Quotes About Education',
#  'Depression Quotes',
#  'Top Reads',
#  'Get Your Hustle On',
#  'Chasing Your Dreams',
#  'Around Positive People',
#  'Get Core Confidence',
#  'Your Mission Statement',
#  'How to Wake Up Ready',
#  'How To Be More Confident',
#  'Get Goal Oriented',
#  'Goals',
#  'Protect Your Vibes',
#  'Mind Blowing Questions',
#  'Remind Yourself',
#  'Purpose Leads To Results',
#  'Fulfill Your Dreams',
#  'When You’re Overwhelmed',
#  'Stand Up',
#  'Stop Expecting from Others',
#  'Before You Go To Sleep',
#  'Keeping Your Dreams',
#  'Small Minds',
#  '25 Top Rap Songs',
#  'Inspiration',
#  'Become Happier',
#  'Before You Quit',
#  'Your Life Summed Up',
#  '2 Hours a Day',
#  'Wasting Time on Facebook',
#  'How To Deal With Regret',
#  'Loneliness Into Reflection',
#  'Voices In Your Head',
#  'Erasing Bad Habits',
#  'Career',
#  'Work From Home',
#  'Lazy Vs. No Passion',
#  'Online Classes and Training',
#  'Pomodoro Technique',
#  'Online Bachelor’s Degree',
#  'Mindset',
#  'Books',
#  'Motivational Books',
#  'Books For Men',
#  'Spiritual Books',
#  'Books for Athletes',
#  'More Articles',
#  'Relationships',
#  'Entrepreneurship',
#  'Good News',
#  'Health',
#  'Interviews and Podcasts on Everyday Power',
#  'Life Advice and Skills',
#  'Money',
#  'Motivational Videos',
#  'Parenting',
#  'Travel',
#  '50 Jaden Smith Quotes That Expand Your Mindset',
#  'Never let anyone else’s light overshadow you. Read these Jaden Smith quotes to find out how.',
#  'By',
#  'Norbert Juma, Lead Editor',
#  'Editor at Everyday Power',
#  'Published on May 5, 2019 1:57 PM EST',
#  'Our latest collection of Jaden Smith quotes on Everyday Power Blog.',
#  'Jaden Smith is an American rapper,',
#  'singer',
#  'and actor best known for appearing in movies such as “The Pursuit of Happyness”, “The Karate Kid” and “After Earth”.',
#  'Besides acting, Smith is a talented musician and has interests in',
#  'business',
#  'as well. After some performances with popular singers like Justin Bieber and releasing a couple of mixtapes, he released his debut studio album, “Syre”, in 2017 and later followed up with “Syre: The Electric Album” in 2018.',
#  'Smith has also been a youth ambassador for Project Zambi, which offers assistance for Zambian children orphaned by AIDS.',
#  'A child of two very famous Hollywood stars, Smith has not let his',
#  'parents',
#  'overshadow his young\xa0career. In that respect, here are some thought-provoking Jaden Smith quotes that will expand your mindset.',
#  'Jaden Smith Quotes That Expand Your Mindset',
#  '1. “If newborn babies could speak they would be the most intelligent beings on planet earth.” –',
#  'Jaden Smith',
#  '2. “The Moment That',
#  'Truth',
#  'Is Organized It Becomes A Lie.”\xa0–',
#  'Jaden Smith',
#  '3. “',
#  'Instagram',
#  'is not the answer.”\xa0–',
#  'Jaden Smith',
#  '4. “You can discover everything you need to know about everything by looking at your hands.” –',
#  'Jaden Smith',
#  '5. “No one believed',
#  'Galileo',
#  'either.”\xa0–',
#  'Jaden Smith',
#  '6. “Being born was the most influential thing that’s ever happened to me, for myself.” –',
#  'Jaden Smith',
#  '7. “When Life Gives You Big Problems, Just Be Happy You Forgot All Your Little Problems.” –',
#  'Jaden Smith',
#  '8. “I’ll never',
#  'read',
#  'every single book or go to every single place. But I’ll die in the trying of it.”\xa0–',
#  'Jaden Smith',
#  '9. “The only way to change something is to shock it. If you want your muscles to grow, you have to shock them. If you want society to change, you have to shock them.” –',
#  'Jaden Smith',
#  '10. “I feel like a serious revolution needs to take place in order for human beings to evolve in a way where we can truly exist as a society.” –',
#  'Jaden Smith',
#  'Thought-provoking Jaden Smith quotes',
#  '11. “If a cupcake falls from a tree how far away will it be from down.” –',
#  'Jaden Smith',
#  '12. “They Distract You With Us So You Don’t Pay Attention To The Missing Girls In Nigeria.” –',
#  'Jaden Smith',
#  '13. “We Need To Stop',
#  'Teaching',
#  'The Youth About The Past And Encourage Them To Change The',
#  'Future',
#  '.”\xa0–',
#  'Jaden Smith',
#  '14. “What is the definition of ‘light’?” –',
#  'Jaden Smith',
#  '15. “Unawareness Is The Only Sin, And If You Were Aware You Would Know.” –',
#  'Jaden Smith',
#  '16. “Trees are never sad look at them every once in a while they’re quite beautiful.” –',
#  'Jaden Smith',
#  '17. “Since we’re family, we both have wins, and we don’t really go against each other, like, ‘I’m gonna kill you,’ ” –',
#  'Jaden Smith',
#  '18. “People Use To Ask Me What Do You Wanna Be When You Get Older And I Would Say What A Stupid Question The Real Question Is What Am I Right Now.” –',
#  'Jaden Smith',
#  '19. “People Think A',
#  'RelationShip',
#  'Makes You Whole, That It’s Two 50%’s Coming Together To Make 100% When It Should Be Two 100%’s Making 200%.”\xa0–',
#  'Jaden Smith',
#  '20. “People Tell Me To',
#  'Smile',
#  'I Tell Them The Lack Of Emotion In My Face Doesn’t Mean I’m Unhappy.”\xa0–',
#  'Jaden Smith',
#  'More Jaden Smith quotes',
#  '21. “We want to create a society that is working for us and with us – and we’re working for society, not against it.” –',
#  'Jaden Smith',
#  '22. “All The Rules In This World Were Made By Someone No Smarter Than You. So Make Your Own.” –',
#  'Jaden Smith',
#  '23. “I would love for there to be a female president.” –',
#  'Jaden Smith',
#  '24. “Everything that I talk about in my music is pretty much just trying to evolve consciousness in the world and help everything become better and brighter.” –',
#  'Jaden Smith',
#  '25. “I just want to teach people how to be',
#  'comfortable',
#  '. Stop being so scared.”\xa0–',
#  'Jaden Smith',
#  '26. “And everything you say is something that you can’t reverse / Something that you can’t rehearse.” –',
#  'Jaden Smith',
#  '27. “I have a goal to be just the craziest person of all time. And when I say craziest, I mean, like, I want to do like Olympic-level things. I want to be the most durable person on the planet,” –',
#  'Jaden Smith',
#  '28. “I Hope It Doesn’t Take For Me To Die For You To See What I Do For You.” –',
#  'Jaden Smith',
#  '29. “When The First Animal Went Extinct That Should’ve Been A Sign.” –',
#  'Jaden Smith',
#  '30. “A question I would like to present to the world is: Where is the love? And what are we doing? Who’s making the decisions that are putting us in the predicaments that we are in, with all of these people losing their lives around the world in so many different ways?” –',
#  'Jaden Smith',
#  'Mystifying Jaden Smith quotes',
#  '31. “Every 7 Years Your Body Is Completely Replaced With Entirely New Cells So Just Because You Look The Same Doesn’t Mean You Are.” –',
#  'Jaden Smith',
#  '32. “How Can Mirrors Be Real If Our Eyes Aren’t Real.” –',
#  'Jaden Smith',
#  '33. “If everybody in the world dropped out of school who would have a much more intelligent society.” –',
#  'Jaden Smith',
#  '34. “I’m Glad That Our Distance Makes Us Witness Ourselves From A Different Entrance.” –',
#  'Jaden Smith',
#  '35. “Either I have only one pair of shoes or every pair you choose.” –',
#  'Jaden Smith',
#  '36. “The more time you spend awake the more time you spend asleep.” –',
#  'Jaden Smith',
#  '37. “Once You Go In You Always Come Out Alive.” –',
#  'Jaden Smith',
#  '38. “Stop Gossiping Reflect Internally You Will Find Yourself A Neglected Part Of Your Self.” –',
#  'Jaden Smith',
#  '39. “If a bookstore never runs out of a certain book, does that mean that nobody reads it, or everybody reads it.”\xa0 –',
#  'Jaden Smith',
#  '40. “Being aware in the moment of right now is just the most important thing. All of our issues come from us not being aware enough or not seeing through our problems to the depths of the issues.” –',
#  'Jaden Smith',
#  'Other Jaden Smith quotes',
#  '41. “Currently Going Through Customs Even Though I Was Born On This Planet.” –',
#  'Jaden Smith',
#  '42. “The world is going to keep bashing me for whatever I do, and I’m going to keep not caring.”-',
#  'Jaden Smith',
#  '43. “Whenever You Disagree With Somebody Just Remember The Dress And Accept That You Guys Are SEEING Two Different Things.” –',
#  'Jaden Smith',
#  '44. “Right now, we do not act as a true society. We act as a world under terror, just scrambling to survive. –',
#  'Jaden Smith',
#  '45. “I’m going to imprint myself on everything in this world.” –',
#  'Jaden Smith',
#  '46. “I Will Always Give You The Truth I Will Never Lie To You In My music If You Can’t Handle My Feelings And',
#  'Emotions',
#  'Please Unfollow Me.”\xa0 –',
#  'Jaden Smith',
#  '47. “I want to be the most durable person on the planet.” –',
#  'Jaden Smith',
#  '48. “When You Live Your Whole Life In A Prison Freedom Can Be So Dull.”\xa0 –',
#  'Jaden Smith',
#  '49. “Here’s the deal: School is not',
#  'authentic',
#  'because it ends. It’s not true, it’s not real. Our learning will never end.” –',
#  'Jaden Smith',
#  '50. “It’s good to be happy and tell us how cool your life is and how awesome you are on',
#  'social media',
#  '. That’s great because it inspires other people to be happy, too. But a lot of times, people are trying to be happy in the wrong ways – with money or with different things that are not true happiness.” –',
#  'Jaden Smith',
#  'Which of these Jaden Smith quotes was your favorite?',
#  'Jaden Smith',
#  'has never been afraid to speak his mind on the issues he cares about. He can always be depended upon to deliver deep, philosophical thoughts whenever he’s in a position to share them. Hopefully, these quotes have jogged your mind and inspired you to think outside the box.',
#  'Did you enjoy these Jaden Smith quotes? Which of the quotes was your favorite? Tell us in the comment section below. We would love to hear all about it.',
#  'READ MORE:',
#  '115 Blessed Quotes Celebrating Your Everyday Blessings',
#  '4 Comments',
#  'Click to view',
#  '4 Comments',
#  'Bert',
#  'August 18, 2020 at 8:46 PM',
#  'Jordan! My mannnnnnn. This shit is tight. I can’t believe my whole life never hearing it before. I am new. I am changrd. Catch me on the mountain. I’m a monk. Thank u my brother',
#  'Reply',
#  'Emmanuel',
#  'March 27, 2019 at 5:51 PM',
#  'Hayden bro I love your music it helps me grow.syre',
#  'Reply',
#  'Keineetse Leshona',
#  'January 3, 2019 at 9:22 AM',
#  'People tell me to smile but “I tell the lack of emotion in my face doesn’t mean that I’m unhappy”. I so love this quote because it just answers all the people who feel one has to smile in order to show their love and appreciation even when they don’t feel like it',
#  'Reply',
#  'Jeffrey I. Moore',
#  'January 5, 2019 at 12:13 AM',
#  'Haha, YES!!',
#  'Reply',
#  'Leave a Reply',
#  'Your email address will not be published.',
#  'Required fields are marked',
#  '*',
#  'Comment',
#  'Name',
#  '*',
#  'Email',
#  '*',
#  'Related Topics:',
#  'quotes',
#  'Rap Inspiration',
#  'Up Next',
#  '30 Kevin Hart quotes on Success, Family and Work Ethic',
#  "Don't Miss",
#  '50 Aretha Franklin Quotes about Love, Life and Respect',
#  'You may like',
#  'Inspirational Quotes',
#  '185 Happy Birthday Quotes for a Friend On Wishes and Success',
#  'Inspirational Quotes',
#  '90 Short Inspirational Quotes to Fuel Your Day',
#  'Inspirational Quotes',
#  '180 Good Morning Text Messages for Her Love',
#  'Inspirational Quotes',
#  '210 Inspirational Quotes for Kids About School, Life, and Success',
#  'Inspirational Quotes',
#  '50 Woodrow Wilson Quotes About Leadership, Humanity, and Progress',
#  'Inspirational Quotes',
#  '50 Stevie Nicks Quotes and Lyrics That Will Unleash Your Inner Rockstar',
#  'Inspirational Quotes',
#  'The 38 Best Mr. Miyagi Quotes to Awaken the Karate Kid in You',
#  'Inspirational Quotes',
#  '40 Mary McLeod Bethune Quotes From the Powerful Civil Rights Leader and Educator',
#  'Inspirational Quotes',
#  '50 Simone de Beauvoir Quotes That Inspired the Feminist Movement',
#  'Inspirational Quotes',
#  '50 Elizabeth Gilbert Quotes That Will Help You Find Your Power',
#  'Inspirational Quotes',
#  '50 Chimamanda Ngozi Adichie Quotes from One of The World’s Leading Feminists',
#  'Inspirational Quotes',
#  '50 Jean-Paul Sartre Quotes About Existentialism',
#  '185 Happy Birthday Quotes for a Friend On Wishes and Success',
#  '90 Short Inspirational Quotes to Fuel Your Day',
#  '180 Good Morning Text Messages for Her Love',
#  '210 Inspirational Quotes for Kids About School, Life, and Success',
#  '50 Woodrow Wilson Quotes About Leadership, Humanity, and Progress',
#  '50 Stevie Nicks Quotes and Lyrics That Will Unleash Your Inner Rockstar',
#  'The 38 Best Mr. Miyagi Quotes to Awaken the Karate Kid in You',
#  '40 Mary McLeod Bethune Quotes From the Powerful Civil Rights Leader and Educator',
#  '50 Simone de Beauvoir Quotes That Inspired the Feminist Movement',
#  '50 Elizabeth Gilbert Quotes That Will Help You Find Your Power',
#  '50 Chimamanda Ngozi Adichie Quotes from One of The World’s Leading Feminists',
#  '50 Jean-Paul Sartre Quotes About Existentialism',
#  'Search',
#  'Latest Articles',
#  '8 Leadership Lessons I Learned From My First Boss',
#  'How To Become More Goal Oriented In Your Life',
#  '185 Happy Birthday Quotes for a Friend On Wishes and Success',
#  '90 Short Inspirational Quotes to Fuel Your Day',
#  '180 Good Morning Text Messages for Her Love',
#  'About Us',
#  'Advertise',
#  'Sitemap',
#  'Contact Us',
#  'Write For Us',
#  'Privacy Policy',
#  'Terms of Service',
#  'EverydayPower.com © 2013 - 2021',
#  'Copy link',
#  'Copy',
#  'Copied',
#  'Powered by',
#  'Social Snap']

# %%
quotes = []
for q in just_text:
    value = re.search("^\d+\.", q)
    if value is not None:
        text = re.sub(r'\d+', '', value.string)
        if (len(text) < 5):
            continue
        text = text[3:]
        text = text.replace('\xa0', "")
        text = text.replace('” –', "")
        quotes.append(text)
print(quotes)
# Out:
# ['If newborn babies could speak they would be the most intelligent beings on planet earth.', 'The Moment That', 'You can discover everything you need to know about everything by looking at your hands.', 'No one believed', 'Being born was the most influential thing that’s ever happened to me, for myself.', 'When Life Gives You Big Problems, Just Be Happy You Forgot All Your Little Problems.', 'I’ll never', 'The only way to change something is to shock it. If you want your muscles to grow, you have to shock them. If you want society to change, you have to shock them.', 'I feel like a serious revolution needs to take place in order for human beings to evolve in a way where we can truly exist as a society.', 'If a cupcake falls from a tree how far away will it be from down.', 'They Distract You With Us So You Don’t Pay Attention To The Missing Girls In Nigeria.', 'We Need To Stop', 'What is the definition of ‘light’?', 'Unawareness Is The Only Sin, And If You Were Aware You Would Know.', 'Trees are never sad look at them every once in a while they’re quite beautiful.', 'Since we’re family, we both have wins, and we don’t really go against each other, like, ‘I’m gonna kill you,’ ', 'People Use To Ask Me What Do You Wanna Be When You Get Older And I Would Say What A Stupid Question The Real Question Is What Am I Right Now.', 'People Think A', 'People Tell Me To', 'We want to create a society that is working for us and with us – and we’re working for society, not against it.', 'All The Rules In This World Were Made By Someone No Smarter Than You. So Make Your Own.', 'I would love for there to be a female president.', 'Everything that I talk about in my music is pretty much just trying to evolve consciousness in the world and help everything become better and brighter.', 'I just want to teach people how to be', 'And everything you say is something that you can’t reverse / Something that you can’t rehearse.', 'I have a goal to be just the craziest person of all time. And when I say craziest, I mean, like, I want to do like Olympic-level things. I want to be the most durable person on the planet,', 'I Hope It Doesn’t Take For Me To Die For You To See What I Do For You.', 'When The First Animal Went Extinct That Should’ve Been A Sign.', 'A question I would like to present to the world is: Where is the love? And what are we doing? Who’s making the decisions that are putting us in the predicaments that we are in, with all of these people losing their lives around the world in so many different ways?', 'Every  Years Your Body Is Completely Replaced With Entirely New Cells So Just Because You Look The Same Doesn’t Mean You Are.', 'How Can Mirrors Be Real If Our Eyes Aren’t Real.', 'If everybody in the world dropped out of school who would have a much more intelligent society.', 'I’m Glad That Our Distance Makes Us Witness Ourselves From A Different Entrance.', 'Either I have only one pair of shoes or every pair you choose.', 'The more time you spend awake the more time you spend asleep.', 'Once You Go In You Always Come Out Alive.', 'Stop Gossiping Reflect Internally You Will Find Yourself A Neglected Part Of Your Self.', 'If a bookstore never runs out of a certain book, does that mean that nobody reads it, or everybody reads it.', 'Being aware in the moment of right now is just the most important thing. All of our issues come from us not being aware enough or not seeing through our problems to the depths of the issues.', 'Currently Going Through Customs Even Though I Was Born On This Planet.', 'The world is going to keep bashing me for whatever I do, and I’m going to keep not caring.”-', 'Whenever You Disagree With Somebody Just Remember The Dress And Accept That You Guys Are SEEING Two Different Things.', 'Right now, we do not act as a true society. We act as a world under terror, just scrambling to survive. –', 'I’m going to imprint myself on everything in this world.', 'I Will Always Give You The Truth I Will Never Lie To You In My music ...

# %%
url = 'https://mashable.com/2014/12/30/jaden-smith-tweets-2014/'
r = requests.get(url)
soup = bs(r.content)
# Out:
# []

# %%
headers = soup.find_all("p")
just_text = [text for text in soup.stripped_strings]
tweets = just_text[144:187]
for t in tweets:
    if t.find("2014") > -1:
        tweets.remove(t)
    if t == "— Jaden Smith (@officialjaden)":
        tweets.remove(t)
    
for t in tweets:
    if t.find("2014") > -1:
        tweets.remove(t)
        
quotes.extend(tweets)

# %%
url = 'https://lyrics.az/jaden-smith/-/best-tweets.html'
r = requests.get(url)

soup = bs(r.content)
text = soup.get_text()
all_text = text.split('\n')
for t in all_text:
    if type(t) is str:
        print(re.search(r'\d+', '', t))
#print(text)
#text = re.sub(r'\d+', '', value.string)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-b213ee63c939> in <module>
#       7 for t in all_text:
#       8     if type(t) is str:
# ----> 9         print(re.search(r'\d+', '', t))
#      10 #print(text)
#      11 #text = re.sub(r'\d+', '', value.string)
#
# ~\anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# ~\anaconda3\lib\re.py in _compile(pattern, flags)
#     302     if not sre_compile.isstring(pattern):
#     303         raise TypeError("first argument must be string or compiled pattern")
# --> 304     p = sre_compile.compile(pattern, flags)
#     305     if not (flags & DEBUG):
#     306         if len(_cache) >= _MAXCACHE:
#
# ~\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~\anaconda3\lib\sre_parse.py in parse(str, flags, state)
#     946
#     947     try:
# --> 948         p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     949     except Verbose:
#     950         # the VERBOSE flag was switched on inside the pattern.  to be
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %%
url = 'https://jadensmithtweetgenerator.tumblr.com/'
r = requests.get(url)
soup = bs(r.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script>
#    var __pbpa = true;
#   </script>
#   <script>
#    var translated_warning_string = 'Warning: Never enter your Tumblr password unless \u201chttps://www.tumblr.com/login\u201d\x0ais the address in your web browser.\x0a\x0aYou should also see a green \u201cTumblr, Inc.\u201d identification in the address bar.\x0a\x0aSpammers and other bad guys use fake forms to steal passwords.\x0a\x0aTumblr will never ask you to log in from a user\u2019s blog.\x0a\x0aAre you absolutely sure you want to continue?';
#   </script>
#   <script language="javascript" src="https://assets.tumblr.com/assets/scripts/pre_tumblelog.js?_v=b9f848c06fcba7eaf305d4a7cb7a1b98" type="text/javascript">
#   </script>
#   <!DOCTYPE html>
#   <script>
#    var __pbpa = true;
#   </script>
#   <script>
#    var translated_warning_string = 'Warning: Never enter your Tumblr password unless \u201chttps://www.tumblr.com/login\u201d\x0ais the address in your web browser.\x0a\x0aYou should also see a green \u201cTumblr, Inc.\u201d identification in the address bar.\x0a\x0aSpammers and other bad guys use fake forms to steal passwords.\x0a\x0aTumblr will never ask you to log in from a user\u2019s blog.\x0a\x0aAre you absolutely sure you want to continue?';
#   </script>
#   <script language="javascript" src="https://assets.tumblr.com/assets/scripts/pre_tumblelog.js?_v=a3e5e7f1b487e101133066aadcff3cde" type="text/javascript">
#   </script>
#   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="Arial" name="font:Body"/>
#   <meta content="#FFFFFF" name="color:Background"/>
#   <meta content="#383737" name="color:Text"/>
#   <meta content="#7e7b7b" name="color:Link"/>
#   <meta content="#DDDDDD" name="color:Borders"/>
#   <meta content="10.5" name="text:Body font size"/>
#   <script type="text/javascript">
#    function generator(){
#
# 			var firstphraselist = [
# 			"dear everyone:",
# 			"Dude,",
# 			"FYI haters,",
# 			"Girl, you so fine. But",
# 			"Jaden says:",
# 			"my pshyche says:",
# 			"I speak jaden.",
# 			"I'm sorry bae, but",
# 			"I've said it before and i'll say it again,",
# 			"it's like i always say,",
# 			"in conclusion,",
# 			"listen,",
# 			"REAL TALK:",
# 			"Sup girl.",
# 			"That feeling when your bae tells you",
# 			"trees be all like",
# 			"Yo",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",
# 			" ",];
#
# 			var secondphraselist = [
# 			 "a book always runs out of paper.",
# 			 "a mindframe is still a frame.",
# 			 "a mirror is only a prison for your reflection.",
# 			 "adults confuse me.",
# 			 "all trees are time travellers.",
# 			 "age isn't a religion.",
# 			 "bats don't need to listen because they can already hear everything.",
# 			 "can you prove human beings CAN'T teleport?",
# 			 "do any of us really have a mind?",
# 			 "do you believe existence believes in you?",
# 			 "does anyone else taste dark matter?",
# 			 "DON'T stay in school.",
# 			 "don't read everything you believe.",
# 			 "don't listen to the distractions.",
# 			 "experience is a choice.",
# 			 "gravity isn't real.",
# 			 "how can someone find themself if they're in school all day?",
# 			 "how come we don't have passports for trees?",
# 			 "how do we know cupcakes aren't afraid to be eaten?",
# 			 "how do you know when you fall asleep that you're not actually waking up?",
# 			 "I am a sad.",
# 			 "I blow my own mind on an hourly basis.",
# 			 "I can't decide if i should take a trip to Norway or Jupiter.",
# 			 "i cry distilled tears.",
# 			 "i don't need to listen to you.",
# 			 "I use two dreamcatchers because just one fills up too quickly.",
# 		     "I'm embaressed for you.",
# 		     "I'm just being real.",
# 		     "I'm looking at trees.",
# 			 "If only all the extinct animals hadn't gone extinct, they would probably be able to talk by now.",
# 			 "If more people were willing to speak the same truth as me the world would be less sad.",
# 			 "if pilot school was necessary then why are there still plane crashes?",
# 			 "if you can't appreciate what i say you can't appreciate honest philosophy and poetry.",
# 			 "if you could speak to babies you would be the most intelligent person on the planet.",
# 			 "if you could weigh thoughts human beings would be the heaviest things on this planet.",
# 			 "if you were born on this planet you can already speak every language in the world.",
# 			 "I am 10,000% lé git.",
# 			 "I don't recognize what you call grammar.",
# 			 "Jake Gyllenhaal.",
# 			 "just like school your grammar can't hold me.",
# 			 "Listen to your mind",
# 			 "Let's meld particles.",
# 			 "let's bond on a cellular level.",
# 			 "Lets get all sad and shit.",
# 			 "look at your hands.",
# 			 "maybe I was born in the wrong dimension.",
# 			 "maybe that's the point.",
# 			 "meet me in the DMs.",
# 			 "meet me on FaceTime and let's talk about SpaceTime.",
# 			 "my young mind is older than you think.",
# 			 "next time you see a tree you should apologize.",
# 			 "no i will not follow trolls.",
# 			 "no one teaches school to teach.",
# 			 "nothing that's worth learning can be taught in school.",
# 			 "our eyes aren't the begining.",
# 			 "realness is my only religion.",
# 			 "school isn't real.",
# 			 "Shia LaBeouf.",
# 			 "some of us are better at time travel than others.",
# 			 "sometimes I am scared by all my wisdom.",
# 			 "trees are immortal so you can't surprise them.",
# 			 "the fact i think about these big questions is proof the universe has a consciousness.",
# 			 "the planet is older than you think.",
# 			 "these thoughts are immortal.",
# 			 "there ain't room in this oxygen chamber for two.",
# 			 "This is what a profound tweet looks like.",
# 			 "trees don't know how to be sad.",
# 			 "trees would run away if they could.",
# 			 "UFOs.",
# 			 "UFOs can see us too.",
# 			 "understanding still leaves you standing.",
# 			 "unlock the Large Hadron Collider in your mind.",
# 			 "we are all the same age because atoms don't age.",
# 			 "why do  police enforce speed limits when the earth is moving at a million miles an hour?",
#              "why do we go to school again?",
#              "you can't fail something you don't believe in.",
#              "you can't force something that isn't real.",
#              "why read something you can experience?",
#              "your 140 characters can't contain me.",
#              "you sound like you still think mirrors are real.",
#              "you should experience more.",
# 			 "you'd be too scared to talk to a real tree.",
# 			 "we are all time travellers.",
# 			 "we are never not looking in a mirror.",
# 			 "we only have one planet...for now.",
# 			 "what do you think the aliens watching us make of all your hatin?",
# 			 "why do i need a passport if i was born on this planet?",
# 			 "why read something you can experience?",
# 			 "yeah i've been to space. what do you think this planet is floating in?",
# 			 "Yo.",
# 			 ]
#
# 			var thirdphraselist = [
#
#              "← If You Cant Handle this kind of raw power and emotion please unfollow me.",
# 			 "← very powerful thought right here.",
# 			 "[Drops Mic]",
# 			 "a tree just whispered that to me in my sleep.",
# 			 "And no, I didn't learn that in ''school''...obviously.",
# 			 "and no, my twitter has not been hacked.",
# 			 "be realer.",
# 			 "Coachella.",
# 			 "cosmic.",
# 			 "Damn, that's some mind-blowing wisdom.",
# 			 "deleting twitter now.",
# 			 "drink nothing but distilled water for a month and you'll see what i mean.",
# 			 "either you get it or you don't.",
# 			 "epic.",
# 			 "hashtag jupiter.",
# 			 "I bet no one has ever said that before.",
# 			 "I can't say much more because I'm *literally* about to transcend.",
# 			 "I know this from first hand experience.",
# 			 "If you don't understand. Maybe that's the point.",
# 			 "It's super obvious when you think about it.",
# 			 "Jaden out.",
# 			 "Keanu Reeves.",
# 			 "kendall gets it and maybe one day you will too.",
# 			 "now, if you excuse me, i have to go have an out-of-body experience.",
# 			 "now, if you excuse me, I have to go stare in the mirror and cry.",
# 			 "now, if you excuse me, I have to go watch Donnie Darko again",
# 			 "on an unrelated note, has anyone seen the new Seth Rogan film? ",
# 			 "PS. I am now inside your head",
# 			 "particles, man.",
#              "Peace.",
# 			 "peace out.",
# 			 "radical.",
# 			 "Remember this.",
# 			 "Shia LaBeouf",
# 			 "sorry if that's too ''real'' for your human brain.",
# 			 "This is why nobody gets me.",
# 			 "That is tight.",
# 			 "this is my art ladies and gentlemen.",
# 			 "this is my art ladies and gentlemen. Peace.",
# 			 "This may be my best tweet ever.",
# 			 "think about that for a second.",
# 			 "Tight.",
# 			 "Totally unrelated, I just saw Day After Tomorrow again. Shit is dope.",
# 			 "Watch Donnie Darko again and you'll see what i mean.",
# 			 "Willow knows what I'm talking about.",
# 			 "you are now excused.",
# 			 "you can have that one for free.",
# 			 "You're welcome.",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 " ",
# 			 ]
#
#
# 			var random1 = parseInt(Math.random() * firstphraselist.length);
# 			var random2 = parseInt(Math.random() * secondphraselist.length);
# 			var random3 = parseInt(Math.random() * thirdphraselist.length);
#
# 			var tweet = firstphraselist[random1] + " " + secondphraselist[random2] + " " + thirdphraselist[random3];
#
# 			var numberroll=Math.floor(Math.random() * 10) + 1;
# 			var finaltweet=""
# 					{
# 					finaltweet=tweet;
# 					}
#
# 			if(document.getElementById("result")){
# 				document.getElementById("placeholder").removeChild(document.getElementById("result"));
# 			}
#
# 			var element = document.createElement("div");
# 			element.setAttribute("id", "result");
# 			element.appendChild(document.createTextNode(finaltweet));
# 			document.getElementById("placeholder").appendChild(element);
# 		}
#
# //web fonts
#   WebFontConfig = {
#     google: { families: [ 'Arvo:400,700:latin', 'Open+Sans:400,300:latin', 'Prata::latin' ] }
#   };
#   (function() {
#     var wf = document.createElement('script');
#     wf.src = ('https:' == document.location.protocol ? 'https' : 'http') +
#       '://ajax.googleapis.com/ajax/libs/webfont/1/webfont.js';
#     wf.type = 'text/javascript';
#     wf.async = 'true';
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(wf, s);
#   })();
#   </script>
#   <!-- Stylesheet CSS -->
#   <style type="text/css">
#    body {
# text-align:left;
# line-height:20px;
# color:#383737;
# background-color:#FFFFFF;
# font-family:'Helvetica Neue', Helvetica, sans-serif;
# font-size: 11px;
# margin:0px;}
#
# a:link, a:active, a:visited{
#     color: #177c8e; text-decoration: none;
# font-family:Arial, 'Helvetica Neue', Helvetica, sans-serif;
#     font-size: 11px;
# }
# a:hover{
#     color: ; text-decoration: none;
#     font-family:Arial, 'Helvetica Neue', Helvetica, sans-serif;
#         font-size: 11px;
#     }
# #content{
#     position: relative;
#     border:0px;
#     margin:0 auto;
#     padding: 60px 20px 0px;
#     width: 620px
#     }
# #generator{
#     width:500px;
#     font: Helvetica;
#     font-weight: 300;
#     line-height: 34px;
#     border:2px solid #8899a6;
#     margin: 0 auto;
#     font-size: 28px;
#     text-transform: capitalize;
#     padding:30px 40px 40px 30px;
#     text-align:none;
#     }
# #generator input{font-size:14px;font-weight:normal;margin-top: 60px}
# #title{
#     font-family: 'Helvetica Neue', Helvetica, sans-serif;
#     font-color:#000000;
#     font-size: 26pt;
#     line-height:30pt;
#     }
#
# #time {
#     font-size: 13px;
#     color: #8899a6;
#     margin-top:-11px;
#     }
#
# iframe {display:none !important;}
#   </style>
#   <style>
#    figure{margin:0}.tmblr-iframe{position:absolute}.tmblr-iframe.hide{display:none}.tmblr-iframe--amp-cta-button{visibility:hidden;position:fixed;bottom:10px;left:50%;transform:translateX(-50%);z-index:100}.tmblr-iframe--amp-cta-button.tmblr-iframe--loaded{visibility:visible;animation:iframe-app-cta-transition .2s ease-out}
#   </style>
#   <link href="https://assets.tumblr.com/client/prod/standalone/blog-network-npf/index.build.css?_v=a6c4ad40cdc663ad83f8a1bbc8aeedc6" media="screen" rel="stylesheet"/>
#   <link href="android-app://com.tumblr/tumblr/x-callback-url/blog?blogName=jadensmithtweetgenerator" rel="alternate"/>
#   <script src="https://assets.tumblr.com/assets/scripts/tumblelog.js?_v=0149f73a9219085ee0b9c224dcc56b13">
#   </script>
#   <link href="https://assets.tumblr.com/fonts/gibson/stylesheet.css?v=3" rel="stylesheet" type="text/css"/>
#   <meta content="off" http-equiv="x-dns-prefetch-control"/>
#   <meta content="Anonymous,it was a bad movie,im bye,moonlightanddust,bye" name="keywords"/>
#   <!-- BEGIN TUMBLR FACEBOOK OPENGRAPH TAGS -->
#   <!-- If you'd like to specify your own Open Graph tags, define the og:url and og:title tags in your theme's HTML. -->
#   <!-- Read more: http://ogp.me/ -->
#   <meta content="48119224995" property="fb:app_id"/>
#   <meta content="Jaden Smith Tweet Generator" property="og:title"/>
#   <meta content="http://jadensmithtweetgenerator.tumblr.com/?og=1" property="og:url"/>
#   <meta content="" property="og:description"/>
#   <meta content="tumblr-feed:tumblelog" property="og:type"/>
#   <meta content="http://38.media.tumblr.com/avatar_dfc9db86a7a3_128.png" property="og:image"/>
#   <meta content="tumblr://x-callback-url/blog?blogName=jadensmithtweetgenerator" property="al:ios:url"/>
#   <meta content="Tumblr" property="al:ios:app_name"/>
#   <meta content="305343404" property="al:ios:app_store_id"/>
#   <meta content="tumblr://x-callback-url/blog?blogName=jadensmithtweetgenerator" property="al:android:url"/>
#   <meta content="Tumblr" property="al:android:app_name"/>
#   <meta content="com.tumblr" property="al:android:package"/>
#   <!-- END TUMBLR FACEBOOK OPENGRAPH TAGS -->
#   <!-- TWITTER TAGS -->
#   <meta charset="utf-8"/>
#   <meta content="tumblr" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="jadensmithtweetgenerator" name="twitter:title"/>
#   <meta content=" " name="twitter:description"/>
#   <meta content="Tumblr" name="twitter:app:name:iphone"/>
#   <meta content="Tumblr" name="twitter:app:name:ipad"/>
#   <meta content="Tumblr" name="twitter:app:name:googleplay"/>
#   <meta content="305343404" name="twitter:app:id:iphone"/>
#   <meta content="305343404" name="twitter:app:id:ipad"/>
#   <meta content="com.tumblr" name="twitter:app:id:googleplay"/>
#   <meta content="tumblr://x-callback-url/blog?blogName=jadensmithtweetgenerator&amp;referrer=twitter-cards" name="twitter:app:url:iphone"/>
#   <meta content="tumblr://x-callback-url/blog?blogName=jadensmithtweetgenerator&amp;referrer=twitter-cards" name="twitter:app:url:ipad"/>
#   <meta content="tumblr://x-callback-url/blog?blogName=jadensmithtweetgenerator&amp;referrer=twitter-cards" name="twitter:app:url:googleplay"/>
#   <link href="android-app://com.tumblr/tumblr/x-callback-url/blog?blogName=jadensmithtweetgenerator" rel="alternate"/>
#   <link href="ios-app://305343404/tumblr/x-callback-url/blog?blogName=jadensmithtweetgenerator" rel="alternate"/>
#   <script src="https://assets.tumblr.com/assets/scripts/tumblelog_post_message_queue.js?_v=a8fadfa499d8cb7c3f8eefdf0b1adfdd">
#   </script>
#   <link href="https://assets.tumblr.com/fonts/gibson/stylesheet.css?v=3" rel="stylesheet" type="text/css"/>
#   <link href="https://jadensmithtweetgenerator.tumblr.com" rel="canonical"/>
#  </head>
#  <body onload="generator()">
#   <div id="content">
#    <p>
#    </p>
#    <center>
#     <input onclick="generator()" type="button" value=" GENERATE ANOTHER"/>
#    </center>
#    <!-- Generator result -->
#    <div id="generator">
#     <img src="http://i.imgur.com/Ap9SIan.png"/>
#     <div id="placeholder">
#     </div>
#     <img src="http://i.imgur.com/ClhaTES.jpg"/>
#     <div id="time">
#      <script type="text/javascript">
#       var d = new Date()
#                 var currentTime = new Date()
#                 var hours = currentTime.getHours()
#                 var minutes = currentTime.getMinutes()
#                 var weekday=new Array("Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday")
#                 var monthname=new Array("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec")
#
# 	                if (minutes < 10)
# 	                minutes = "0" + minutes
#
#                     var suffix = "AM";
# 	                if (hours >= 12) {
# 	                suffix = "PM";
# 	                hours = hours - 12;
# 	                }
# 	                if (hours == 0) {
# 	                hours = 12;
# 	                }
#
#         document.write(hours + ":" + minutes + " " + suffix)
#         document.write(" - ")
#         document.write(d.getDate() + " ")
#         document.write(monthname[d.getMonth()] + " ")
#         document.write(d.getFullYear())
#      </script>
#     </div>
#    </div>
#   </div>
#   <br/>
#   <center>
#    <div style="font-size:8px">
#     <a href="https://twitter.com/freddiecampion" target="_blank">
#      [made by]
#     </a>
#    </div>
#    <!-- BEGIN TUMBLR CODE -->
#    <iframe frameborder="0" height="1" id="ga_target" scrolling="no" style="background-color:transparent; overflow:hidden; position:absolute; top:0; left:0; z-index:9999;" width="1">
#    </iframe>
#    <script type="text/javascript">
#     (function(){
#         var analytics_frame = document.getElementById('ga_target');
#         var analytics_iframe_loaded;
#         var user_logged_in;
#         var blog_is_nsfw = 'No';
#
#         var eventMethod = window.addEventListener ? "addEventListener" : "attachEvent";
#         var eventer = window[eventMethod];
#         var messageEvent = eventMethod == "attachEvent" ? "onmessage" : "message";
#         eventer(messageEvent,function(e) {
#             var message = (e.data && e.data.split) ? e.data.split(';') : '';
#             switch (message[0]) {
#                 case 'analytics_iframe_loaded':
#                     analytics_iframe_loaded = true;
#                     postCSMessage();
#                     postGAMessage();
#                     break;
#                 case 'user_logged_in':
#                     user_logged_in = message[1];
#                     postGAMessage();
#                     break;
#             }
#         }, false);
#
#         analytics_frame.src = "https://assets.tumblr.com/analytics.html?bf3144497974403e60441586bd7d5270#http://jadensmithtweetgenerator.tumblr.com";
#         function postGAMessage() {
#             if (analytics_iframe_loaded && user_logged_in) {
#                 var is_ajax = false;
#                 analytics_frame.contentWindow.postMessage(['tick_google_analytics', is_ajax, user_logged_in, blog_is_nsfw, '/?route=%2F'].join(';'), analytics_frame.src.split('/analytics.html')[0]);
#             }
#         }
#         function postCSMessage() {
#             COMSCORE = true;
#             analytics_frame.contentWindow.postMessage('enable_comscore;' + window.location, analytics_frame.src.split('/analytics.html')[0]);
#         }
#     })();
#    </script>
#    <script>
#     var _qevents = _qevents || [];
#             (function() {
#                 var s = document.createElement('script');
#                 var el = document.getElementsByTagName('script')[0];
#                 s.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
#                 el.parentNode.insertBefore(s, el);
#             })();
#    </script>
#    <script type="text/javascript">
#     _qevents.push( { qacct: 'p-19UtqE8ngoZbM' } );
#    </script>
#    <noscript>
#     <div style="display: none;">
#      <img alt="Quantcast" height="1" src="//pixel.quantserve.com/pixel/'p-19UtqE8ngoZbM'.gif" width="1"/>
#     </div>
#    </noscript>
#    <script type="text/javascript">
#     !function(s){s.src='https://www.tumblr.com/impixu?T=1404398590&J=eyJ0eXBlIjoidXJsIiwidXJsIjoiaHR0cDpcL1wvYmVuZWRpY3RjdW1iZXJiYXRjaGdlbmVyYXRvci50dW1ibHIuY29tXC8iLCJyZXF0eXBlIjowLCJyb3V0ZSI6IlwvIn0=&U=ILHJCIHAMN&K=2ae744b611ecfeed30eb92bcf93954e0583131f844f94a08dbd382e5783d94b8&R=https%3A%2F%2Fwww.google.com%2F'.replace(/&R=[^&$]*/,'').concat('&R='+escape(document.referrer)).slice(0,2000).replace(/%.?.?$/,'');}(new Image());
#    </script>
#    <noscript>
#     <img src="https://www.tumblr.com/impixu?T=1404398590&amp;J=eyJ0eXBlIjoidXJsIiwidXJsIjoiaHR0cDpcL1wvYmVuZWRpY3RjdW1iZXJiYXRjaGdlbmVyYXRvci50dW1ibHIuY29tXC8iLCJyZXF0eXBlIjowLCJyb3V0ZSI6IlwvIiwibm9zY3JpcHQiOjF9&amp;U=ILHJCIHAMN&amp;K=b2b4e1c16b510735dc52e3356cd5415a7ef129ba7edd40f76ae1d632a4175c41&amp;R=https%3A%2F%2Fwww.google.com%2F" style="position:absolute;z-index:-3334;top:0px;left:0px;visibility:hidden;"/>
#    </noscript>
#    <script type="text/javascript">
#     !function(s){s.src='https://www.tumblr.com/impixu?T=1404398590&J=...&U=EOEBOFFMOC&K=47172a3af3184b1d675c7ec565476e688726fd8040af54f62de29308760485b1&R=https%3A%2F%2Fwww.google.com%2F'.replace(/&R=[^&$]*/,'').concat('&R='+escape(document.referrer)).slice(0,2000).replace(/%.?.?$/,'');}(new Image());
#    </script>
#    <noscript>
#     <img src="https://www.tumblr.com/impixu?T=1404398590&amp;J=...&amp;U=EOEBOFFMOC&amp;K=fbf1ca5e39e09ef1b14dcbaf3fab11401704925b7644f99f7f5004c6c11b8250&amp;R=https%3A%2F%2Fwww.google.com%2F" style="position:absolute;z-index:-3334;top:0px;left:0px;visibility:hidden;"/>
#    </noscript>
#    <script>
#     (function() {
#                         var s = document.createElement('script');
#                         var el = document.getElementsByTagName('script')[0];
#                         s.src = ('https:' == document.location.protocol ? 'https://s' : 'http://l') + '.yimg.com/ss/rapid-3.18.1.js';
#                         s.onload = function(){
#                             var YAHOO = window.YAHOO;
#                             if (YAHOO) {
#                                 var keys = {
#                                     pd:'/',
#                                     _li:0,
#                                     b_id:93203619,
#                                     i_rad:0,
#                                     i_strm:0
#                                 };
#                                 var conf = {
#                                                                         spaceid:1197716038,
#                                     client_only:1,
#                                     yql_enabled:false,
#                                     keys:keys,
#                                     nol:1
#                                 };
#                                 YAHOO.rapid = new YAHOO.i13n.Rapid(conf);
#                             }
#                         };
#                         el.parentNode.insertBefore(s, el);
#                     })();
#    </script>
#    <iframe class="tumblr_controls" frameborder="0" height="1" id="tumblr_controls" scrolling="no" src="https://assets.tumblr.com/assets/html/iframe/o.html?_v=f6a711049f5b0ff998b7521f9f7f6f2c#src=http%3A%2F%2Fjadensmithtweetgenerator.tumblr.com%2F&amp;lang=en_US&amp;name=jadensmithtweetgenerator&amp;avatar=http%3A%2F%2F31.media.tumblr.com%2Favatar_dfc9db86a7a3_64.png&amp;title=Jaden+Smith+Tweet+Generator&amp;url=http%3A%2F%2Fjadensmithtweetgenerator.tumblr.com%2F&amp;page_slide=slide" width="1">
#    </iframe>
#    <div id="teaser_iframe_container" style="display:none;">
#     <iframe frameborder="0" height="1" id="teaser_iframe" scrolling="no" src="https://www.tumblr.com/assets/html/iframe/teaser.html?_v=bf5ad879aefcdc1fc32a5e5803217109#src=http%3A%2F%2Fjadensmithtweetgenerator.tumblr.com%2F&amp;lang=en_US&amp;name=jadensmithtweetgenerator&amp;avatar=http%3A%2F%2F31.media.tumblr.com%2Favatar_dfc9db86a7a3_64.png&amp;title=Jaden+smith+Tweet+Generator&amp;url=http%3A%2F%2Fjadensmithtweetgenerator.tumblr.com%2F&amp;page_slide=slide" width="1">
#     </iframe>
#    </div>
#    <script type="text/javascript">
#     (function(Tumblr){
#         var follow_iframe_initialized = false;
#         if (Tumblr.FollowTeaser && Tumblr.PostMessageListener) {
#             // Don't do anything until the first initialize event
#             Tumblr.PostMessageListener.initialize(function(message, origin) {
#                 if (follow_iframe_initialized || message.length < 2) return;
#
#                 if (message[0] === 'follow_iframe' && message[1] === 'enable') {
#                     Tumblr.FollowTeaser.current_page = 1;
#                     Tumblr.FollowTeaser.infer_infinite_scroll = true;
#                     Tumblr.FollowTeaser.create_from_tumblr_controls("http:\/\/assets.tumblr.com\/assets\/html\/iframe\/follow.html?_v=715979144cad7368561a5e13fd17dac8");
#                     Tumblr.FollowTeaser.scroll_listener(true);
#                     follow_iframe_initialized = true;
#                 }
#             });
#         }
#     })(this.Tumblr || (this.Tumblr = {}));
#    </script>
#    <!--[if IE]><script type="text/javascript">document.getElementById('tumblr_controls').allowTransparency=true;</script><![endif]-->
#    <!-- END TUMBLR CODE -->
#    <iframe frameborder="0" height="1" id="ga_target" scrolling="no" style="background-color:transparent; overflow:hidden; position:absolute; top:0; left:0; z-index:9999;" width="1">
#    </iframe>
#    <script type="text/javascript">
#     (function(){
#         var analytics_frame = document.getElementById('ga_target');
#         var analytics_iframe_loaded;
#         var user_logged_in;
#         var blog_is_nsfw = 'No';
#
#         var eventMethod = window.addEventListener ? "addEventListener" : "attachEvent";
#         var eventer = window[eventMethod];
#         var messageEvent = eventMethod == "attachEvent" ? "onmessage" : "message";
#         eventer(messageEvent,function(e) {
#             var message = (e.data && e.data.split) ? e.data.split(';') : '';
#             switch (message[0]) {
#                 case 'analytics_iframe_loaded':
#                     analytics_iframe_loaded = true;
#                     postCSMessage();
#                     postGAMessage();
#                     break;
#                 case 'user_logged_in':
#                     user_logged_in = message[1];
#                     postGAMessage();
#                     break;
#             }
#         }, false);
#
#         analytics_frame.src = "https://assets.tumblr.com/analytics.html?_v=9f5febfd57a8a649c598d888f2d9e062#" +
#                               "https://jadensmithtweetgenerator.tumblr.com";
#         function postGAMessage() {
#             if (analytics_iframe_loaded && user_logged_in) {
#                 var is_ajax = false;
#                 analytics_frame.contentWindow.postMessage(['tick_google_analytics', is_ajax, user_logged_in, blog_is_nsfw, '/?route=%2F'].join(';'), analytics_frame.src.split('/analytics.html')[0]);
#             }
#         }
#         function postCSMessage() {
#             COMSCORE = true;
#             analytics_frame.contentWindow.postMessage('enable_comscore;' + window.location, analytics_frame.src.split('/analytics.html')[0]);
#         }
#     })();
#    </script>
#    <script nonce="fAYSEMf8coIuTIQCmPOgYO5Vr4" type="text/javascript">
#     !function(s){s.src='https://px.srvcs.tumblr.com/impixu?T=1610059034&J=eyJ0eXBlIjoidXJsIiwidXJsIjoiaHR0cDovL2phZGVuc21pdGh0d2VldGdlbmVyYXRvci50dW1ibHIuY29tLyIsInJlcXR5cGUiOjAsInJvdXRlIjoiLyJ9&U=GKMKGBMOGF&K=25e3fffff00462334fa865649d5ea60668616cf9aba7b6356a5a3a025e8288bf&R='.replace(/&R=[^&$]*/,'').concat('&R='+escape(document.referrer)).slice(0,2000).replace(/%.?.?$/,'');}(new Image());
#    </script>
#    <noscript>
#     <img src="https://px.srvcs.tumblr.com/impixu?T=1610059034&amp;J=eyJ0eXBlIjoidXJsIiwidXJsIjoiaHR0cDovL2phZGVuc21pdGh0d2VldGdlbmVyYXRvci50dW1ibHIuY29tLyIsInJlcXR5cGUiOjAsInJvdXRlIjoiLyIsIm5vc2NyaXB0IjoxfQ==&amp;U=GKMKGBMOGF&amp;K=48439afb61f8143241ebd638c127990ef6398660064a19e40db1574f94176526&amp;R=" style="position:absolute;z-index:-3334;top:0px;left:0px;visibility:hidden;"/>
#    </noscript>
#    <noscript data-bootstrap="{&quot;Components&quot;:{&quot;PostActivity&quot;:[],&quot;NotificationPoller&quot;:{&quot;messaging_keys&quot;:[],&quot;token&quot;:&quot;c86f8a500596474a7ef5034081f694bd&quot;,&quot;inbox_unread&quot;:0},&quot;DesktopDashboardLogo&quot;:{&quot;animations&quot;:[[&quot;https:\/\/assets.tumblr.com\/images\/logo\/hover-animations\/1.png?_v=161861acded461bb6e995593a3bae835&quot;,&quot;https:\/\/assets.tumblr.com\/images\/logo\/hover-animations\/1@2x.png?_v=496a774637302a598c851381d00009b0&quot;]]},&quot;TumblelogIframe&quot;:{&quot;unified&quot;:true,&quot;variant&quot;:null,&quot;isCompact&quot;:true,&quot;tumblelogBundleSrc&quot;:&quot;https:\/\/assets.tumblr.com\/client\/prod\/standalone\/tumblelog\/index.build.js?_v=6be13416468978ab5fb9e5691b0323f3&quot;,&quot;tumblelogName&quot;:&quot;jadensmithtweetgenerator&quot;,&quot;isLoggedIn&quot;:false,&quot;isFriend&quot;:false,&quot;formKey&quot;:&quot;&quot;,&quot;canSubscribe&quot;:false,&quot;isSubscribed&quot;:false,&quot;tumblelogTitle&quot;:&quot;Jaden Smith Tweet Generator&quot;,&quot;tumblelogAvatar&quot;:&quot;https:\/\/64.media.tumblr.com\/avatar_30808ddf8235_64.pnj&quot;,&quot;tumblelogAvatar128&quot;:&quot;https:\/\/64.media.tumblr.com\/avatar_30808ddf8235_128.pnj&quot;,&quot;tumblelogHost&quot;:&quot;https:\/\/jadensmithtweetgenerator.tumblr.com&quot;,&quot;isOptica&quot;:false,&quot;isCustomTheme&quot;:true,&quot;themeHeaderImage&quot;:&quot;https:\/\/assets.tumblr.com\/images\/default_header\/optica_pattern_14.png?_v=8c2d3b00544b7efbc4ac06dc3f80e374&quot;,&quot;themeBackgroundColor&quot;:&quot;#FAFAFA&quot;,&quot;themeTitleColor&quot;:&quot;#444444&quot;,&quot;themeAccentColor&quot;:&quot;#529ECC&quot;,&quot;brag&quot;:true,&quot;adsEnabled&quot;:true,&quot;canShowAd&quot;:true,&quot;isPremium&quot;:false,&quot;showLrecAds&quot;:false,&quot;showStickyLrecBackfill&quot;:false,&quot;showGeminiAds&quot;:false,&quot;geminiSectionCodeDesktop&quot;:&quot;a10bca9c-0c5d-4a02-ab13-14ab8513d81d&quot;,&quot;geminiSectionCodeMobile&quot;:&quot;ced63809-b609-4aca-96a0-abc099acba6b&quot;,&quot;currentPageType&quot;:&quot;blog&quot;,&quot;currentPage&quot;:1,&quot;searchQuery&quot;:&quot;&quot;,&quot;tag&quot;:&quot;&quot;,&quot;query&quot;:&quot;&quot;,&quot;chrono&quot;:false,&quot;postId&quot;:&quot;&quot;,&quot;src&quot;:&quot;https:\/\/jadensmithtweetgenerator.tumblr.com\/&quot;,&quot;postUrl&quot;:&quot;&quot;,&quot;isBlocked&quot;:null,&quot;isAdmin&quot;:false,&quot;lookupButtonUrl&quot;:&quot;&quot;,&quot;showSpamButton&quot;:false,&quot;showRootPostButton&quot;:false,&quot;rootPostUrl&quot;:&quot;&quot;,&quot;showRadarPostButton&quot;:false,&quot;radarKeys&quot;:&quot;&quot;,&quot;isUniblocked&quot;:false,&quot;isNsfw&quot;:false,&quot;isAdult&quot;:false,&quot;isSpam&quot;:false,&quot;isPrimaryBlog&quot;:false,&quot;canEdit&quot;:false,&quot;canReblogSelf&quot;:false,&quot;showLikeButton&quot;:false,&quot;showReblogButton&quot;:false,&quot;reblogUrl&quot;:&quot;&quot;,&quot;showFanMailButton&quot;:false,&quot;showMessagingButton&quot;:false,&quot;loginCheckIframeSrc&quot;:&quot;https:\/\/assets.tumblr.com\/assets\/html\/iframe\/login_check.html?_v=3de94a184d600617102ddd5b48fb36e9&quot;,&quot;appInstallUrls&quot;:{&quot;android&quot;:&quot;https:\/\/play.google.com\/store\/apps\/details?id=com.tumblr\u0026referrer=utm_source%3Dtumblr%26utm_medium%3Diframe%26utm_campaign%3Dbn_continue_or_install_cta&quot;,&quot;ios&quot;:&quot;https:\/\/apps.apple.com\/app\/apple-store\/id305343404?pt=212308\u0026ct=bn_continue_or_install_cta\u0026mt=8&quot;},&quot;appOpenReferrer&quot;:&quot;bn_header_open_btn&quot;,&quot;isShowSearch&quot;:true,&quot;supplyLogging&quot;:[],&quot;secondsSinceLastActivity&quot;:-1,&quot;installUrlOpenFailed&quot;:{&quot;android&quot;:&quot;https:\/\/play.google.com\/store\/apps\/details?id=com.tumblr\u0026referrer=utm_source%3Dtumblr%26utm_medium%3Diframe%26utm_campaign%3Dbn_header_app_open_failed&quot;,&quot;ios&quot;:&quot;h ...
#    </noscript>
#    <script src="https://assets.tumblr.com/client/prod/standalone/tumblelog/index.build.js?_v=6be13416468978ab5fb9e5691b0323f3">
#    </script>
#   </center>
#  </body>
# </html>

# %%
# just_text = [text for text in soup.stripped_strings]
# print(just_text)
firstphraselist = [ "dear everyone:",
			"Dude,",
			"FYI haters,",
			"Girl, you so fine. But",
			"Jaden says:",
			"my pshyche says:",
			"I speak jaden.",
			"I'm sorry bae, but",
			"I've said it before and i'll say it again,",
			"it's like i always say,",
			"in conclusion,",
			"listen,",
			"REAL TALK:",
			"Sup girl.",
			"That feeling when your bae tells you",
			"trees be all like",
			"Yo"]

secondphaselist = ["a book always runs out of paper.",
			 "a mindframe is still a frame.",
			 "a mirror is only a prison for your reflection.",
			 "adults confuse me.",
			 "all trees are time travellers.",
			 "age isn't a religion.", 
			 "bats don't need to listen because they can already hear everything.",
			 "can you prove human beings CAN'T teleport?",
			 "do any of us really have a mind?",
			 "do you believe existence believes in you?",
			 "does anyone else taste dark matter?",
			 "DON'T stay in school.",
			 "don't read everything you believe.",
			 "don't listen to the distractions.",
			 "experience is a choice.",
			 "gravity isn't real.",
			 "how can someone find themself if they're in school all day?",
			 "how come we don't have passports for trees?",
			 "how do we know cupcakes aren't afraid to be eaten?",
			 "how do you know when you fall asleep that you're not actually waking up?",
			 "I am a sad.",
			 "I blow my own mind on an hourly basis.",
			 "I can't decide if i should take a trip to Norway or Jupiter.",
			 "i cry distilled tears.",
			 "i don't need to listen to you.",
			 "I use two dreamcatchers because just one fills up too quickly.",
		     "I'm embaressed for you.",
		     "I'm just being real.",
		     "I'm looking at trees.",
			 "If only all the extinct animals hadn't gone extinct, they would probably be able to talk by now.",
			 "If more people were willing to speak the same truth as me the world would be less sad.",
			 "if pilot school was necessary then why are there still plane crashes?",
			 "if you can't appreciate what i say you can't appreciate honest philosophy and poetry.",
			 "if you could speak to babies you would be the most intelligent person on the planet.",
			 "if you could weigh thoughts human beings would be the heaviest things on this planet.",
			 "if you were born on this planet you can already speak every language in the world.",
			 "I am 10,000% lé git.",
			 "I don't recognize what you call grammar.",
			 "Jake Gyllenhaal.",
			 "just like school your grammar can't hold me.",
			 "Listen to your mind",
			 "Let's meld particles.",
			 "let's bond on a cellular level.",
			 "Lets get all sad and shit.",
			 "look at your hands.",
			 "maybe I was born in the wrong dimension.",
			 "maybe that's the point.",
			 "meet me in the DMs.",
			 "meet me on FaceTime and let's talk about SpaceTime.",
			 "my young mind is older than you think.",
			 "next time you see a tree you should apologize.",
			 "no i will not follow trolls.",
			 "no one teaches school to teach.",
			 "nothing that's worth learning can be taught in school.",
			 "our eyes aren't the begining.",
			 "realness is my only religion.",
			 "school isn't real.",
			 "Shia LaBeouf.",
			 "some of us are better at time travel than others.",
			 "sometimes I am scared by all my wisdom.",
			 "trees are immortal so you can't surprise them.",
			 "the fact i think about these big questions is proof the universe has a consciousness.",
			 "the planet is older than you think.",
			 "these thoughts are immortal.",
			 "there ain't room in this oxygen chamber for two.",
			 "This is what a profound tweet looks like.",
			 "trees don't know how to be sad.",
			 "trees would run away if they could.",
			 "UFOs.",
			 "UFOs can see us too.",
			 "understanding still leaves you standing.",
			 "unlock the Large Hadron Collider in your mind.",
			 "we are all the same age because atoms don't age.",
			 "why do  police enforce speed limits when the earth is moving at a million miles an hour?",
             "why do we go to school again?",
             "you can't fail something you don't believe in.",
             "you can't force something that isn't real.",
             "why read something you can experience?",
             "your 140 characters can't contain me.",
             "you sound like you still think mirrors are real.",
             "you should experience more.",
			 "you'd be too scared to talk to a real tree.",
			 "we are all time travellers.",
			 "we are never not looking in a mirror.",
			 "we only have one planet...for now.",
			 "what do you think the aliens watching us make of all your hatin?",
			 "why do i need a passport if i was born on this planet?",
			 "why read something you can experience?",
			 "yeah i've been to space. what do you think this planet is floating in?",
			 "Yo."]
			 
thirdphraselist = [ 
             "← If You Cant Handle this kind of raw power and emotion please unfollow me.",
			 "← very powerful thought right here.",
			 "[Drops Mic]",
			 "a tree just whispered that to me in my sleep.",
			 "And no, I didn't learn that in ''school''...obviously.",
			 "and no, my twitter has not been hacked.", 
			 "be realer.",
			 "Coachella.",
			 "cosmic.",
			 "Damn, that's some mind-blowing wisdom.",
			 "deleting twitter now.",
			 "drink nothing but distilled water for a month and you'll see what i mean.",
			 "either you get it or you don't.",
			 "epic.",
			 "hashtag jupiter.",
			 "I bet no one has ever said that before.",
			 "I can't say much more because I'm *literally* about to transcend.",
			 "I know this from first hand experience.",
			 "If you don't understand. Maybe that's the point.",
			 "It's super obvious when you think about it.",
			 "Jaden out.",
			 "Keanu Reeves.",
			 "kendall gets it and maybe one day you will too.",
			 "now, if you excuse me, i have to go have an out-of-body experience.",
			 "now, if you excuse me, I have to go stare in the mirror and cry.",
			 "now, if you excuse me, I have to go watch Donnie Darko again",
			 "on an unrelated note, has anyone seen the new Seth Rogan film? ",
			 "PS. I am now inside your head",
			 "particles, man.",
             "Peace.",
			 "peace out.",
			 "radical.",
			 "Remember this.",
			 "Shia LaBeouf",
			 "sorry if that's too ''real'' for your human brain.",
			 "This is why nobody gets me.",   
			 "That is tight.",
			 "this is my art ladies and gentlemen.",
			 "this is my art ladies and gentlemen. Peace.",
			 "This may be my best tweet ever.",
			 "think about that for a second.",
			 "Tight.",
			 "Totally unrelated, I just saw Day After Tomorrow again. Shit is dope.",
			 "Watch Donnie Darko again and you'll see what i mean.",
			 "Willow knows what I'm talking about.",
			 "you are now excused.",
			 "you can have that one for free.",
			 "You're welcome."]
print(firstphraselist, secondphaselist, thirdphraselist)
# Out:
# []
# ['dear everyone:', 'Dude,', 'FYI haters,', 'Girl, you so fine. But', 'Jaden says:', 'my pshyche says:', 'I speak jaden.', "I'm sorry bae, but", "I've said it before and i'll say it again,", "it's like i always say,", 'in conclusion,', 'listen,', 'REAL TALK:', 'Sup girl.', 'That feeling when your bae tells you', 'trees be all like', 'Yo'] ['a book always runs out of paper.', 'a mindframe is still a frame.', 'a mirror is only a prison for your reflection.', 'adults confuse me.', 'all trees are time travellers.', "age isn't a religion.", "bats don't need to listen because they can already hear everything.", "can you prove human beings CAN'T teleport?", 'do any of us really have a mind?', 'do you believe existence believes in you?', 'does anyone else taste dark matter?', "DON'T stay in school.", "don't read everything you believe.", "don't listen to the distractions.", 'experience is a choice.', "gravity isn't real.", "how can someone find themself if they're in school all day?", "how come we don't have passports for trees?", "how do we know cupcakes aren't afraid to be eaten?", "how do you know when you fall asleep that you're not actually waking up?", 'I am a sad.', 'I blow my own mind on an hourly basis.', "I can't decide if i should take a trip to Norway or Jupiter.", 'i cry distilled tears.', "i don't need to listen to you.", 'I use two dreamcatchers because just one fills up too quickly.', "I'm embaressed for you.", "I'm just being real.", "I'm looking at trees.", "If only all the extinct animals hadn't gone extinct, they would probably be able to talk by now.", 'If more people were willing to speak the same truth as me the world would be less sad.', 'if pilot school was necessary then why are there still plane crashes?', "if you can't appreciate what i say you can't appreciate honest philosophy and poetry.", 'if you could speak to babies you would be the most intelligent person on the planet.', 'if you could weigh thoughts human beings would be the heaviest things on this planet.', 'if you were born on this planet you can already speak every language in the world.', 'I am 10,000% lé git.', "I don't recognize what you call grammar.", 'Jake Gyllenhaal.', "just like school your grammar can't hold me.", 'Listen to your mind', "Let's meld particles.", "let's bond on a cellular level.", 'Lets get all sad and shit.', 'look at your hands.', 'maybe I was born in the wrong dimension.', "maybe that's the point.", 'meet me in the DMs.', "meet me on FaceTime and let's talk about SpaceTime.", 'my young mind is older than you think.', 'next time you see a tree you should apologize.', 'no i will not follow trolls.', 'no one teaches school to teach.', "nothing that's worth learning can be taught in school.", "our eyes aren't the begining.", 'realness is my only religion.', "school isn't real.", 'Shia LaBeouf.', 'some of us are better at time travel than others.', 'sometimes I am scared by all my wisdom.', "trees are immortal so you can't surprise them.", 'the fact i think about these big questions is proof the universe has a consciousness.', 'the planet is older than you think.', 'these thoughts are immortal.', "there ain't room in this oxygen chamber for two.", 'This is what a profound tweet looks like.', "trees don't know how to be sad.", 'trees would run away if they could.', 'UFOs.', 'UFOs can see us too.', 'understanding still leaves you standing.', 'unlock the Large Hadron Collider in your mind.', "we are all the same age because atoms don't age.", 'why do  police enforce speed limits when the earth is moving at a million miles an hour?', 'why do we go to school again?', "you can't fail something you don't believe in.", "you can't force something that isn't real.", 'why read something you can experience?', "your 140 characters can't contain me.", 'you sound like you still think mirrors are real.', 'you should experience more.', "you'd be too scared to talk to a real tree.", 'we are all time travellers.', 'we are never not looking in a ...

# %%
#try again
import twitter
import os
import config

# %%
api = twitter.Api(consumer_key=config.API_KEY,
  consumer_secret=config.secret_key,
    access_token_key=config.access_token,
    access_token_secret=config.access_token_secret)

# %%
def get_tweets(api=None, screen_name=None):
    timeline = api.GetUserTimeline(screen_name=screen_name, count=200)
    earliest_tweet = min(timeline, key=lambda x: x.id).id
    print("getting tweets before:", earliest_tweet)

    while True:
        tweets = api.GetUserTimeline(
            screen_name=screen_name, max_id=earliest_tweet, count=200
        )
        new_earliest = min(tweets, key=lambda x: x.id).id

        if not tweets or new_earliest == earliest_tweet:
            break
        else:
            earliest_tweet = new_earliest
            print("getting tweets before:", earliest_tweet)
            timeline += tweets

    return timeline

# %%
timeline = api.GetUserTimeline(screen_name='jaden', count=250)
for t in timeline:
    if not t.text.startswith("RT") and t.text.find('https://t.co') == -1 and t.text.find('@') == -1:
        quotes.append(t.text)
        print(t.text)
# Out:
# You Gotta Break My Heart Or The Rain Won’t Stop.
# RIP DOOM
# Watched Wonder Woman Last Night And Cried.
# The Holidays Remind Me Of How Weird I Am.
# Flowers &amp; Soft Rain
# Lol
# Cold Love
# #MOTM3
# I Released #CTV1 Merch To Honor My Day 1s. |||
# #LifeInAYear
# My Fault I Thought We Was Catching Vibes.
# Hey, I’m Here For You.
# I Feel Like I’ve Been Looking For A Graphic Designer And Product Manager For My Whole Life.
# Never Go Inside Cellphones At Night
# The Algorithms Figured Out Were Not Hanging Out Anymore lol.
# Yung Superhero’s
# I’m Ready.
# I’m Wall Running For The Flex, Pete Told Me I Was Next.
# In That Shirt
# Did I Lie
# There’s A Lake On The Moon
# These Vision Racers Are So Comfortable I’mma Cry.
# Stranger Things Better Come Back
# Pay Attention To What M.I.A Says At The Very End, It’s Not Just Us.
# Trippy Summer Freestyle inc
# Y’all Ready To Vote
# Still Can’t Believe Thats How We Met.
# Drops Of Sun
# She’s Been Looking For The Summer.

# %%
print(quotes)
# Out:
# ['If newborn babies could speak they would be the most intelligent beings on planet earth.', 'The Moment That', 'You can discover everything you need to know about everything by looking at your hands.', 'No one believed', 'Being born was the most influential thing that’s ever happened to me, for myself.', 'When Life Gives You Big Problems, Just Be Happy You Forgot All Your Little Problems.', 'I’ll never', 'The only way to change something is to shock it. If you want your muscles to grow, you have to shock them. If you want society to change, you have to shock them.', 'I feel like a serious revolution needs to take place in order for human beings to evolve in a way where we can truly exist as a society.', 'If a cupcake falls from a tree how far away will it be from down.', 'They Distract You With Us So You Don’t Pay Attention To The Missing Girls In Nigeria.', 'We Need To Stop', 'What is the definition of ‘light’?', 'Unawareness Is The Only Sin, And If You Were Aware You Would Know.', 'Trees are never sad look at them every once in a while they’re quite beautiful.', 'Since we’re family, we both have wins, and we don’t really go against each other, like, ‘I’m gonna kill you,’ ', 'People Use To Ask Me What Do You Wanna Be When You Get Older And I Would Say What A Stupid Question The Real Question Is What Am I Right Now.', 'People Think A', 'People Tell Me To', 'We want to create a society that is working for us and with us – and we’re working for society, not against it.', 'All The Rules In This World Were Made By Someone No Smarter Than You. So Make Your Own.', 'I would love for there to be a female president.', 'Everything that I talk about in my music is pretty much just trying to evolve consciousness in the world and help everything become better and brighter.', 'I just want to teach people how to be', 'And everything you say is something that you can’t reverse / Something that you can’t rehearse.', 'I have a goal to be just the craziest person of all time. And when I say craziest, I mean, like, I want to do like Olympic-level things. I want to be the most durable person on the planet,', 'I Hope It Doesn’t Take For Me To Die For You To See What I Do For You.', 'When The First Animal Went Extinct That Should’ve Been A Sign.', 'A question I would like to present to the world is: Where is the love? And what are we doing? Who’s making the decisions that are putting us in the predicaments that we are in, with all of these people losing their lives around the world in so many different ways?', 'Every  Years Your Body Is Completely Replaced With Entirely New Cells So Just Because You Look The Same Doesn’t Mean You Are.', 'How Can Mirrors Be Real If Our Eyes Aren’t Real.', 'If everybody in the world dropped out of school who would have a much more intelligent society.', 'I’m Glad That Our Distance Makes Us Witness Ourselves From A Different Entrance.', 'Either I have only one pair of shoes or every pair you choose.', 'The more time you spend awake the more time you spend asleep.', 'Once You Go In You Always Come Out Alive.', 'Stop Gossiping Reflect Internally You Will Find Yourself A Neglected Part Of Your Self.', 'If a bookstore never runs out of a certain book, does that mean that nobody reads it, or everybody reads it.', 'Being aware in the moment of right now is just the most important thing. All of our issues come from us not being aware enough or not seeing through our problems to the depths of the issues.', 'Currently Going Through Customs Even Though I Was Born On This Planet.', 'The world is going to keep bashing me for whatever I do, and I’m going to keep not caring.”-', 'Whenever You Disagree With Somebody Just Remember The Dress And Accept That You Guys Are SEEING Two Different Things.', 'Right now, we do not act as a true society. We act as a world under terror, just scrambling to survive. –', 'I’m going to imprint myself on everything in this world.', 'I Will Always Give You The Truth I Will Never Lie To You In My music ...
